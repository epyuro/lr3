# %% [markdown]
# # Форматы данных (1)

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 4: Форматы данных"
# * https://docs.python.org/3/library/json.html
# * https://docs.python.org/3/library/pickle.html
# * https://www.crummy.com/software/BeautifulSoup/bs4/doc.ru/bs4ru.html
# * Уэс Маккини. Python и анализ данных

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Вывести все адреса электронной почты, содержащиеся в адресной книге `addres-book.json`

# %% [markdown]
# 2. Вывести телефоны, содержащиеся в адресной книге `addres-book.json`

# %% [markdown]
# 3. По данным из файла `addres-book-q.xml` сформировать список словарей с телефонами каждого из людей.

# %% [markdown]
# ## Лабораторная работа №4

# %% [markdown]
# ### JSON

# %% [markdown]
# 1.1 Считайте файл `contributors_sample.json`. Воспользовавшись модулем `json`, преобразуйте содержимое файла в соответствующие объекты python. Выведите на экран информацию о первых 3 пользователях.

# %%
import json
with open("contributors_sample.json", "r") as read_file:
    data = json.load(read_file)
for i in range(3):
    print(data[i])
# Out:
# {'username': 'uhebert', 'name': 'Lindsey Nguyen', 'sex': 'F', 'address': '01261 Cameron Spring\nTaylorfurt, AK 97791', 'mail': 'jsalazar@gmail.com', 'jobs': ['Energy engineer', 'Engineer, site', 'Environmental health practitioner', 'Biomedical scientist', 'Jewellery designer'], 'id': 35193}
# {'username': 'vickitaylor', 'name': 'Cheryl Lewis', 'sex': 'F', 'address': '66992 Welch Brooks\nMarshallshire, ID 56004', 'mail': 'bhudson@gmail.com', 'jobs': ['Music therapist', 'Volunteer coordinator', 'Designer, interior/spatial'], 'id': 91970}
# {'username': 'sheilaadams', 'name': 'Julia Allen', 'sex': 'F', 'address': 'Unit 1632 Box 2971\nDPO AE 23297', 'mail': 'darren44@yahoo.com', 'jobs': ['Management consultant', 'Engineer, structural', 'Lecturer, higher education', 'Theatre manager', 'Designer, textile'], 'id': 1848091}

# %% [markdown]
# 1.2 Выведите уникальные почтовые домены, содержащиеся в почтовых адресах людей

# %%
data_mail = []
for i in range(len(data)):
    data_mail.append(data[i]['mail'])
for i in range(3):
    print(data_mail[i])
# Out:
# jsalazar@gmail.com
# bhudson@gmail.com
# darren44@yahoo.com

# %% [markdown]
# 1.3 Напишите функцию, которая по `username` ищет человека и выводит информацию о нем. Если пользователь с заданным `username` отсутствует, возбудите исключение `ValueError`

# %%
def search_user(username):
    counter = 0
    for i in range(len(data)):
        if data[i]['username'] == username:
            counter += 1
            print(data[i])
    if counter == 0:
        raise ValueError
        
search_user('sheilaadams')
# Out:
# {'username': 'sheilaadams', 'name': 'Julia Allen', 'sex': 'F', 'address': 'Unit 1632 Box 2971\nDPO AE 23297', 'mail': 'darren44@yahoo.com', 'jobs': ['Management consultant', 'Engineer, structural', 'Lecturer, higher education', 'Theatre manager', 'Designer, textile'], 'id': 1848091}

# %% [markdown]
# 1.4 Посчитайте, сколько мужчин и женщин присутсвует в этом наборе данных.

# %%
female_count = 0 
male_count = 0
for i in range(len(data)):
    if data[i]['sex'] == 'F':
        female_count += 1
    else:
        male_count += 1
print(male_count, female_count)
# Out:
# 2064 2136

# %% [markdown]
# 1.5 Создайте `pd.DataFrame` `contributors`, имеющий столбцы `id`, `username` и `sex`.

# %%
import pandas as pd

contributors = pd.DataFrame(data, columns = ['id', 'username', 'sex'])

contributors.head(3)
# Out:
#         id     username sex
# 0    35193      uhebert   F
# 1    91970  vickitaylor   F
# 2  1848091  sheilaadams   F

# %% [markdown]
# 1.6 Загрузите данные из файла `recipes_sample.csv` (__ЛР2__) в таблицу `recipes`. Объедините `recipes` с таблицей `contributors` с сохранением строк в том случае, если информация о человеке отсутствует в JSON-файле. Для скольких человек информация отсутствует?

# %%
data2 = pd.read_csv('recipes_sample.csv', sep = ',')
recipes = pd.DataFrame(data2)
recipes.head(3)

data3 = contributors.merge(recipes, left_on='id', right_on = 'contributor_id', how = 'inner')
print(len(data) - data3['contributor_id'].nunique())
# Out:
# 0

# %% [markdown]
# ### pickle

# %% [markdown]
# 2.1 На основе файла `contributors_sample.json` создайте словарь следующего вида:
# ```
# {
#     должность: [список username людей, занимавших эту должность]
# }
# ```

# %%
dict1 = {}
works = []

for i in range(len(data)):
    for j in range(len(data[i]['jobs'])):      
        if data[i]['jobs'][j] not in works:
            works.append(data[i]['jobs'][j])

dict2 = dict1.fromkeys(works)

for i in range(len(data)):    
    for j in range(len(data[i]['jobs'])):
        if(data[i]['jobs'][j] in dict2.keys()):
            str = data[i]['jobs'][j]
            dict2[str] = data[i]['username']

# %% [markdown]
# 2.2 Сохраните результаты в файл `job_people.pickle` и в файл `job_people.json` с использованием форматов pickle и JSON соответственно. Сравните объемы получившихся файлов. При сохранении в JSON укажите аргумент `indent`.

# %%
import pickle
with open('job_people.pickle', 'wb') as f:
    pickle.dump(dict2, f)

    
with open("job_people.json", "w") as write_file:
    json.dump(dict2, write_file)

# %% [markdown]
# 2.3 Считайте файл `job_people.pickle` и продемонстрируйте, что данные считались корректно.

# %%
with open('job_people.pickle', 'rb') as f:
    data_new = pickle.load(f)
data_new
# Out:
# {'Energy engineer': 'clintonjones',
#  'Engineer, site': 'baileyvictoria',
#  'Environmental health practitioner': 'kathleenbarnett',
#  'Biomedical scientist': 'brandi41',
#  'Jewellery designer': 'harrisonjeffery',
#  'Music therapist': 'gmoore',
#  'Volunteer coordinator': 'geraldmcdonald',
#  'Designer, interior/spatial': 'steven33',
#  'Management consultant': 'mark32',
#  'Engineer, structural': 'lmathews',
#  'Lecturer, higher education': 'carterpatricia',
#  'Theatre manager': 'samuel80',
#  'Designer, textile': 'tpratt',
#  'Mechanical engineer': 'brendahill',
#  'Retail banker': 'stevenspencer',
#  'Barrister': 'smolina',
#  'Network engineer': 'tvillegas',
#  'Youth worker': 'tara46',
#  'Primary school teacher': 'brian89',
#  'Engineer, broadcasting (operations)': 'millsbrandy',
#  'Designer, ceramics/pottery': 'rrangel',
#  'Engineer, energy': 'avilachelsea',
#  'Engineer, manufacturing': 'linda67',
#  'Designer, furniture': 'mcleanvanessa',
#  'Sport and exercise psychologist': 'michellecollins',
#  'Hospital pharmacist': 'alexrussell',
#  'Surveyor, minerals': 'lmartinez',
#  'Geochemist': 'laurie16',
#  'Restaurant manager': 'youngjoseph',
#  'Clinical psychologist': 'pcallahan',
#  'Sports development officer': 'tonysmith',
#  'Firefighter': 'emiller',
#  'Charity fundraiser': 'carrmonique',
#  'Insurance underwriter': 'stephaniemoore',
#  'Analytical chemist': 'medinadean',
#  'Holiday representative': 'pamela63',
#  'Scientist, research (physical sciences)': 'carolharris',
#  'Financial planner': 'medinakenneth',
#  'Psychiatric nurse': 'medinakenneth',
#  'Audiological scientist': 'cruzchristian',
#  'Programmer, applications': 'gonzalezshawn',
#  'Phytotherapist': 'fergusonjerry',
#  'Records manager': 'stephaniemoore',
#  'Secondary school teacher': 'lpruitt',
#  'Futures trader': 'alexrussell',
#  'Programmer, multimedia': 'rwilliams',
#  'Public affairs consultant': 'nelsonchristy',
#  'Therapeutic radiographer': 'jonesmiguel',
#  'IT trainer': 'xmitchell',
#  'Location manager': 'kennethfoster',
#  'Production engineer': 'nwest',
#  'Chief Operating Officer': 'kblack',
#  'Hospital doctor': 'amanda85',
#  'Radiation protection practitioner': 'enelson',
#  'Printmaker': 'nelsonrachel',
#  'Publishing copy': 'dalton03',
#  'Research scientist (life sciences)': 'rleblanc',
#  'Chief Technology Officer': 'brownbrandon',
#  'Call centre manager': 'johnsonmatthew',
#  'Chief Executive Officer': 'ltran',
#  'Purchasing manager': 'priceryan',
#  'Engineer, petroleum': 'progers',
#  'Social researcher': 'ronaldvaldez',
#  'Publishing rights manager': 'amanda85',
#  'Tax adviser': 'xwilliams',
#  'Customer service manager': 'monique00',
#  'Forensic psychologist': 'smithdanielle',
#  'Financial adviser': 'veronicaschmitt',
#  'Photographer': 'dward',
#  'Health and safety adviser': 'susanguerrero',
#  'Product/process development scientist': 'ericacarpenter',
#  'Ceramics designer': 'josephcourtney',
#  'Secretary/administrator': 'kevin60',
#  'Patent attorney': 'ypowell',
#  'Hotel manager': 'linda67',
#  'Quantity surveyor': 'katie56',
#  'Forest/woodland manager': 'carterpatricia',
#  'Administrator, education': 'ronaldatkinson',
#  'Nurse, adult': 'brendahill',
#  'Multimedia programmer': 'jonesnancy',
#  'Civil Service fast streamer': 'lambertjimmy',
#  'Psychologist, prison and probation services': 'taylor66',
#  'Armed forces training and education officer': 'garciajenna',
#  'Glass blower/designer': 'lmartinez',
#  'Pharmacist, hospital': 'carolyn64',
#  'Warehouse manager': 'nwest',
#  'Psychologist, counselling': 'selliott',
#  'Pensions consultant': 'robert81',
#  'Trade mark attorney': 'vincentmoore',
#  'Psychotherapist, child': 'james57',
#  'Bonds trader': 'zthompson',
#  'Journalist, broadcasting': 'vasquezjoy',
#  'Advice worker': 'wjones',
#  'Geologist, wellsite': 'richard23',
#  'Toxicologist': 'garrettcody',
#  'Media buyer': 'timothy68',
#  'Engineer, civil (consulting)': 'jamesfritz',
#  'Corporate treasurer': 'herringrobert',
#  'Nature conservation officer': 'garrettcody',
#  'Neurosurgeon': 'kblack',
#  'Special effects artist': 'george48',
#  'Professor Emeritus': 'deborahalvarez',
#  'Rural practice surveyor': 'zbrown',
#  'Education administrator': 'ypowell',
#  'Arboriculturist': 'kristinaray',
#  'Facilities manager': 'kathleenbarnett',
#  'Water engineer': 'mark32',
#  'Cabin crew': 'tnorris',
#  'Radiographer, diagnostic': 'oanderson',
#  'Chemist, analytical': 'hparks',
#  'Osteopath': 'morganross',
#  'Insurance claims handler': 'zthompson',
#  'Quality manager': 'donnagonzalez',
#  'Designer, exhibition/display': 'tammykennedy',
#  'Sub': 'wandamcguire',
#  'Market researcher': 'ajones',
#  'Colour technologist': 'jeremyryan',
#  'Emergency planning/management officer': 'mejianicholas',
#  'Lexicographer': 'andrew92',
#  'Water quality scientist': 'smithjennifer',
#  'Engineer, water': 'theresa02',
#  'Surveyor, insurance': 'medinakenneth',
#  'Environmental manager': 'heatherbauer',
#  'Maintenance engineer': 'barrettmolly',
#  "Nurse, children's": 'hhoffman',
#  'Astronomer': 'kayala',
#  'Archaeologist': 'leebarbara',
#  'Journalist, newspaper': 'brittany31',
#  'Accountant, chartered': 'nicole47',
#  'Computer games developer': 'millsbrandy',
#  'Drilling engineer': 'carrmonique',
#  'Librarian, academic': 'karensilva',
#  'Biomedical engineer': 'pamela63',
#  'Haematologist': 'brandi41',
#  'Presenter, broadcasting': 'christopher55',
#  'Surveyor, commercial/residential': 'kevin60',
#  'Engineer, electronics': 'ryanbarajas',
#  'Surveyor, land/geomatics': 'haroldgreen',
#  'Accountant, chartered management': 'ronaldvaldez',
#  'Broadcast engineer': 'michaelmitchell',
#  'Engineer, building services': 'xwilliams',
#  'Patent examiner': 'charles74',
#  'Media planner': 'mmccullough',
#  'Ecologist': 'evanscasey',
#  'Geographical information systems officer': 'devon98',
#  'Paramedic': 'angelawalker',
#  'Designer, television/film set': 'millerjames',
#  'Public librarian': 'rrangel',
#  'Petroleum engineer': 'devon98',
#  'Sales professional, IT': 'xbrown',
#  'Clinical molecular geneticist': 'traceyleblanc',
#  'Commercial art gallery manager': 'coxandrew',
#  'Television/film/video producer': 'andrew92',
#  'Dispensing optician': 'christina88',
#  'Buyer, industrial': 'melinda57',
#  'Energy manager': 'angelawalker',
#  'Structural engineer': 'nicolewhite',
#  'Chief Strategy Officer': 'nwest',
#  'Building control surveyor': 'zburnett',
#  'Product designer': 'deantimothy',
#  'Surveyor, planning and development': 'lambertjimmy',
#  'Architect': 'zburnett',
#  'Dietitian': 'murraynicholas',
#  'Engineer, chemical': 'pinedaseth',
#  'Transport planner': 'laura08',
#  'Therapist, sports': 'sherrianderson',
#  'Scientist, audiological': 'jason85',
#  'Learning mentor': 'april95',
#  'Air broker': 'meyermaria',
#  'Oceanographer': 'opatel',
#  'Psychotherapist, dance movement': 'brandi41',
#  'Physicist, medical': 'haroldgreen',
#  'Equities trader': 'ssims',
#  'Dance movement psychotherapist': 'lmartinez',
#  'Electrical engineer': 'kevinshelton',
#  'Site engineer': 'nharding',
#  'Occupational psychologist': 'leebarbara',
#  'Merchandiser, retail': 'douglashendricks',
#  'Planning and development surveyor': 'jordan42',
#  'Environmental education officer': 'xmitchell',
#  'Arts development officer': 'tammykennedy',
#  'Horticultural therapist': 'figueroajulie',
#  'Recruitment consultant': 'zbrown',
#  'Editor, magazine features': 'darlene15',
#  'Scientist, forensic': 'nelsonrachel',
#  'Geologist, engineering': 'hsimmons',
#  'IT sales professional': 'brightleah',
#  'Psychologist, educational': 'kennethfoster',
#  'Risk analyst': 'kennethfoster',
#  'Scientist, research (life sciences)': 'george48',
#  'Technical sales engineer': 'baileyvictoria',
#  'Adult nurse': 'cindy77',
#  'Animal nutritionist': 'amy84',
#  'English as a foreign language teacher': 'samuel80',
#  'Manufacturing systems engineer': 'sarapacheco',
#  'Orthoptist': 'tharris',
#  'Financial trader': 'virginiaduncan',
#  'Clinical cytogeneticist': 'lee99',
#  'Nurse, learning disability': 'youngheidi',
#  'Chief of Staff': 'jonesmiguel',
#  'Child psychotherapist': 'wayne04',
#  'Seismic interpreter': 'michelledecker',
#  'Retail manager': 'rlong',
#  'Logistics and distribution manager': 'thomassmith',
#  'Merchant navy officer': 'reynoldspatricia',
#  'Microbiologist': 'zacosta',
#  'Librarian, public': 'paula33',
#  'Education officer, community': 'pinedaseth',
#  'Fitness centre manager': 'clintonjones',
#  'Gaffer': 'alanroberts',
#  'Theatre director': 'jonesnancy',
#  'Aeronautical engineer': 'katherinewalters',
#  'Research officer, government': 'jack57',
#  'Television camera operator': 'johnsonmatthew',
#  'Administrator': 'donnagonzalez',
#  'Dealer': 'christina47',
#  'Surveyor, building': 'smolina',
#  'Broadcast presenter': 'zburnett',
#  'Nurse, mental health': 'hbaker',
#  'Curator': 'smithjennifer',
#  'Aid worker': 'amy84',
#  'Press sub': 'nicole47',
#  'Conservation officer, historic buildings': 'priceryan',
#  'Insurance account manager': 'kristina07',
#  'Public relations officer': 'jeffrey05',
#  'Teaching laboratory technician': 'george48',
#  'Air traffic controller': 'samuel80',
#  'Occupational hygienist': 'charlesmark',
#  'Surgeon': 'adamhill',
#  'Civil engineer, consulting': 'anthony87',
#  'Insurance broker': 'wluna',
#  'Magazine journalist': 'ijackson',
#  'Chartered accountant': 'jonesshane',
#  'Counsellor': 'haroldgreen',
#  'Newspaper journalist': 'hsimmons',
#  'Surveyor, rural practice': 'wgray',
#  'Occupational therapist': 'stricklanddevon',
#  'Educational psychologist': 'devon98',
#  'Retail buyer': 'brownlaura',
#  'Mining engineer': 'hparks',
#  'Investment banker, corporate': 'hparks',
#  'Journalist, magazine': 'williamslisa',
#  'Graphic designer': 'jonathanmartinez',
#  'Medical sales representative': 'heatherbauer',
#  'Sports administrator': 'nhobbs',
#  'Stage manager': 'oyoung',
#  'Broadcast journalist': 'tanderson',
#  'Development worker, community': 'pware',
#  'Surveyor, hydrographic': 'ltran',
#  'Estate agent': 'melissahart',
#  'Scientist, physiological': 'tvillegas',
#  'Event organiser': 'timothy68',
#  'Housing manager/officer': 'jenny35',
#  'Lawyer': 'bruce73',
#  'Systems developer': 'vlee',
#  'Engineer, aeronautical': 'rachelwise',
#  'Exhibition designer': 'nharding',
#  'Brewing technologist': 'timothy68',
#  'Television production assistant': 'april95',
#  'Embryologist, clinical': 'trevinorachel',
#  'Trading standards officer': 'brobertson',
#  'Actuary': 'carterpatricia',
#  'Restaurant manager, fast food': 'april95',
#  'International aid/development worker': 'monique00',
#  "Politician's assistant": 'sandra18',
#  'Environmental consultant': 'robertsaudrey',
#  'Sports therapist': 'gnichols',
#  'Biochemist, clinical': 'emilylopez',
#  'Sports coach': 'lpruitt',
#  'Airline pilot': 'jessicanewton',
#  'Health and safety inspector': 'vhoward',
#  'Cytogeneticist': 'millerjames',
#  'Furniture designer': 'ebrown',
#  'Paediatric nurse': 'melissahart',
#  'Tax inspector': 'knightjoan',
#  'Bookseller': 'traceyleblanc',
#  'Set designer': 'umoore',
#  'Meteorologist': 'cathy36',
#  'Community development worker': 'evelynmathis',
#  'Control and instrumentation engineer': 'rwilliams',
#  'Producer, television/film/video': 'lopezjaclyn',
#  'Charity officer': 'april95',
#  'Historic buildings inspector/conservation officer': 'katierobbins',
#  'Lighting technician, broadcasting/film/video': 'douglashendricks',
#  'Careers adviser': 'peterzimmerman',
#  'Product manager': 'campbellemily',
#  'Designer, multimedia': 'lee99',
#  'Licensed conveyancer': 'hoodcheryl',
#  'Archivist': 'eguzman',
#  'Ship broker': 'willismartin',
#  'Copywriter, advertising': 'tarahunt',
#  'Hydrogeologist': 'gabriel79',
#  'Hydrographic surveyor': 'michellecollins',
#  'Financial controller': 'michelle53',
#  'Fashion designer': 'thomasreginald',
#  'Cartographer': 'leahdonovan',
#  'Scientist, water quality': 'john91',
#  'Furniture conservator/restorer': 'cynthiaadams',
#  'Public relations account executive': 'terri81',
#  'Research officer, trade union': 'clintonjones',
#  'Museum/gallery curator': 'triciaknapp',
#  'Print production planner': 'cruzchristian',
#  'Musician': 'jenny35',
#  'Education officer, museum': 'urhodes',
#  'Games developer': 'willismartin',
#  'Counselling psychologist': 'oyoung',
#  'Museum/gallery conservator': 'erinjones',
#  'Marketing executive': 'jordan42',
#  'Production designer, theatre/television/film': 'jodi82',
#  'Translator': 'sfox',
#  'Chief Financial Officer': 'pware',
#  'Claims inspector/assessor': 'karensilva',
#  'Radio broadcast assistant': 'nelsonchristy',
#  'Insurance risk surveyor': 'ajones',
#  'Government social research officer': 'kmccormick',
#  'Special educational needs teacher': 'fergusonjerry',
#  'Horticultural consultant': 'imccarthy',
#  'Administrator, arts': 'stevenspencer',
#  'Legal secretary': 'stevengilbert',
#  'Legal executive': 'priceryan',
#  'Therapist, drama': 'pamela63',
#  'Investment banker, operational': 'gnichols',
#  'Advertising account planner': 'sarahfoley',
#  'Higher education careers adviser': 'daviddunn',
#  'Scientist, product/process development': 'tvillegas',
#  'Diagnostic radiographer': 'trevinorachel',
#  'Scientific laboratory technician': 'pjohnson',
#  'Teacher, special educational needs': 'youngjoseph',
#  'Proofreader': 'murraynicholas',
#  'Clinical scientist, histocompatibility and immunogenetics': 'melissamorse',
#  'Psychotherapist': 'brendahill',
#  'Animal technologist': 'cynthiaadams',
#  'Company secretary': 'vkeller',
#  'Senior tax professional/tax inspector': 'heatherbauer',
#  'Producer, radio': 'wrightgregory',
#  'Retail merchandiser': 'tonysmith',
#  'Learning disability nurse': 'rachel78',
#  'Designer, graphic': 'hsimmons',
#  'Tourism officer': 'sarah62',
#  "Barrister's clerk": 'zthompson',
#  'Research officer, political party': 'wmcdaniel',
#  'Heritage manager': 'tharris',
#  'Consulting civil engineer': 'michelle47',
#  'Conservator, furniture': 'kjohnson',
#  'Software engineer': 'kristina07',
#  'Outdoor activities/education manager': 'garrettrebecca',
#  'Clothing/textile technologist': 'pinedaseth',
#  'Industrial buyer': 'geraldmcdonald',
#  'Health physicist': 'millerjames',
#  'Operations geologist': 'jessicanewton',
#  'Scientist, research (medical)': 'patrick34',
#  'Conservator, museum/gallery': 'emilylopez',
#  'Health service manager': 'gpearson',
#  'Garment/textile technologist': 'kathleenbarnett',
#  'Engineer, biomedical': 'taylor66',
#  'Agricultural engineer': 'blakemiranda',
#  'Soil scientist': 'virginiaduncan',
#  'Secretary, company': 'peterzimmerman',
#  'Wellsite geologist': 'morgan82',
#  'Conference centre manager': 'cindy77',
#  'Nutritional therapist': 'sheila97',
#  'Fast food restaurant manager': 'tina65',
#  'Equality and diversity officer': 'simpsonamber',
#  'Public house manager': 'hbaker',
#  'Scientist, marine': 'lmartinez',
#  'Therapist, horticultural': 'stephaniemoore',
#  'Commissioning editor': 'ashleyhale',
#  'Clinical research associate': 'mark21',
#  'Immunologist': 'tammy32',
#  'Personnel officer': 'mistyray',
#  'Chiropractor': 'anthony87',
#  'Information systems manager': 'juantaylor',
#  'Artist': 'katherinewalters',
#  'Medical secretary': 'tammy32',
#  'Administrator, charities/voluntary organisations': 'msmith',
#  'Armed forces operational officer': 'james57',
#  'Best boy': 'johnibarra',
#  'Ophthalmologist': 'fergusonjerry',
#  'Administrator, sports': 'nicole93',
#  'Pathologist': 'lopezjaclyn',
#  'Engineering geologist': 'rwilliams',
#  'Tour manager': 'ashley59',
#  'Air cabin crew': 'ganderson',
#  'Further education lecturer': 'andersonbrandy',
#  'Minerals surveyor': 'michaelwagner',
#  'Buyer, retail': 'georgedavis',
#  'Information officer': 'oyoung',
#  'Physiological scientist': 'ajones',
#  'Video editor': 'urhodes',
#  'Chief Marketing Officer': 'tammy32',
#  'Human resources officer': 'smithdanielle',
#  'Theatre stage manager': 'garrettcody',
#  'Mudlogger': 'lmathews',
#  'Editor, film/video': 'coxandrew',
#  'Statistician': 'melissamorse',
#  'Chartered management accountant': 'jo06',
#  'Engineer, maintenance': 'ijackson',
#  'Office manager': 'oyoung',
#  'Electronics engineer': 'coxandrew',
#  'Engineer, technical sales': 'ericowen',
#  'Tree surgeon': 'barbara93',
#  'Database administrator': 'traci94',
#  'Academic librarian': 'timothy68',
#  'Pension scheme manager': 'jordanwalters',
#  'Geneticist, molecular': 'zachary61',
#  'Communications engineer': 'cruzchristian',
#  'Conservation officer, nature': 'bbutler',
#  'Barista': 'george48',
#  'Travel agency manager': 'ztucker',
#  'Lecturer, further education': 'andrew92',
#  'Commercial/residential surveyor': 'zbrown',
#  'Mental health nurse': 'garrettcody',
#  'Financial risk analyst': 'lpruitt',
#  'Radiographer, therapeutic': 'christina47',
#  'Accountant, chartered public finance': 'stevenspencer',
#  'Dentist': 'rwilliams',
#  'Estate manager/land agent': 'peterzimmerman',
#  'Research scientist (maths)': 'gabriel79',
#  'Corporate investment banker': 'tanderson',
#  'Interpreter': 'haynesmeredith',
#  'Building services engineer': 'opatel',
#  'Training and development officer': 'devin39',
#  'Teacher, early years/pre': 'johnsontracy',
#  'Therapist, speech and language': 'simpsonamber',
#  'Television floor manager': 'ericowen',
#  'Teacher, secondary school': 'michaeljustin',
#  'Optician, dispensing': 'nicolewhite',
#  'Radio producer': 'erinjones',
#  'Operational researcher': 'murraynicholas',
#  'Materials engineer': 'barrettrebecca',
#  'Comptroller': 'barrettrebecca',
#  'Private music teacher': 'youngheidi',
#  'Town planner': 'kathryn70',
#  'Clinical embryologist': 'lee99',
#  'Chartered public finance accountant': 'trevinodawn',
#  'Contracting civil engineer': 'katie63',
#  'Advertising art director': 'flemingmeghan',
#  'Teacher, English as a foreign language': 'lmartinez',
#  'Psychologist, sport and exercise': 'michelle53',
#  'Doctor, hospital': 'timothyknight',
#  'Contractor': 'glennroberson',
#  'Farm manager': 'vasquezjoy',
#  'Interior and spatial designer': 'kevin60',
#  'Health visitor': 'urangel',
#  'Technical author': 'sharon80',
#  'Recycling officer': 'jonesadam',
#  'Optometrist': 'john33',
#  'Geoscientist': 'laurie16',
#  'Fine artist': 'monique00',
#  'Press photographer': 'romerokristen',
#  'Police officer': 'aalexander',
#  'Editor, commissioning': 'imoreno',
#  'Sound technician, broadcasting/film/video': 'carolyn64',
#  'Catering manager': 'amy79',
#  'Hydrologist': 'katie63',
#  'Banker': 'russellchristopher',
#  'Chiropodist': 'haynesmeredith',
#  'Homeopath': 'marygreen',
#  'Copy': 'wmcdaniel',
#  'Land/geomatics surveyor': 'gpayne',
#  'Designer, industrial/product': 'coxandrew',
#  'Magazine features editor': 'patrick34',
#  'Building surveyor': 'stevengilbert',
#  'Medical technical officer': 'hhoffman',
#  'Engineer, maintenance (IT)': 'romerokristen',
#  'Social worker': 'trevinodawn',
#  'Engineer, control and instrumentation': 'herreranatasha',
#  'Midwife': 'fcline',
#  'Chemical engineer': 'laura08',
#  'Administrator, local government': 'james57',
#  'Adult guidance worker': 'gpayne',
#  'Podiatrist': 'beniteztravis',
#  'Waste management officer': 'enelson',
#  'Architectural technologist': 'laurie16',
#  'Civil engineer, contracting': 'gonzalezshawn',
#  'Animator': 'katierobbins',
#  'Local government officer': 'christopher55',
#  'Horticulturist, amenity': 'erica42',
#  'Accommodation manager': 'robertsaudrey',
#  'Financial manager': 'katkins',
#  'Telecommunications researcher': 'brightleah',
#  'Theme park manager': 'wmcgee',
#  'Diplomatic Services operational officer': 'ebrown',
#  'Textile designer': 'charles74',
#  'Medical illustrator': 'brandi41',
#  'Exercise physiologist': 'lopezjaclyn',
#  'Automotive engineer': 'barrettmolly',
#  'Sales executive': 'bruce73',
#  'Physiotherapist': 'john33',
#  'Engineer, land': 'ssims',
#  'Geophysicist/field seismologist': 'mmccullough',
#  'Camera operator': 'ssims',
#  'Solicitor, Scotland': 'teresa76',
#  'TEFL teacher': 'amy84',
#  'Acupuncturist': 'brobertson',
#  'Art therapist': 'brightleah',
#  'Surveyor, quantity': 'anthonypowell',
#  'Advertising copywriter': 'wellscarmen',
#  'Designer, jewellery': 'cynthiaadams',
#  'Armed forces logistics/support/administrative officer': 'umoore',
#  'Amenity horticulturist': 'sarapacheco',
#  'Risk manager': 'pware',
#  'Oncologist': 'tara46',
#  'Clinical biochemist': 'anthony87',
#  'Probation officer': 'cindy77',
#  'Multimedia specialist': 'gpayne',
#  'Surveyor, mining': 'jamesfritz',
#  'Fisheries officer': 'carolyn64',
#  'Social research officer, government': 'dalton03',
#  'Careers information officer': 'zbrown',
#  'Psychologist, clinical': 'mcdonaldjennifer',
#  'Film/video editor': 'selenamcconnell',
#  'Scientist, research (maths)': 'johnsonmatthew',
#  'Chartered certified accountant': 'nicolewhite',
#  'Museum/gallery exhibitions officer': 'jose78',
#  'Designer, blown glass/stained glass': 'christophercobb',
#  'Data processing manager': 'traciewells',
#  'Education officer, environmental': 'christina68',
#  'Investment analyst': 'beniteztravis',
#  'Higher education lecturer': 'kjohnson',
#  'Illustrator': 'erinjones',
#  'Development worker, international aid': 'christina47',
#  'Engineer, mining': 'kayala',
#  'Regulatory affairs officer': 'timothy68',
#  'Art gallery manager': 'maybrandi',
#  'Tourist information centre manager': 'angelawalker',
#  'Landscape architect': 'gmurphy',
#  'Programme researcher, broadcasting/film/video': 'hwright',
#  'Land': 'douglashendricks',
#  'Metallurgist': 'melissamorse',
#  'Visual merchandiser': 'bruce73',
#  'IT technical support officer': 'charles74',
#  'Early years teacher': 'progers',
#  'Teacher, music': 'andrewsalinas',
#  'Programmer, systems': 'deborahalvarez',
#  'Loss adjuster, chartered': 'mark32',
#  'Engineer, drilling': 'gsanchez',
#  'Marine scientist': 'robertsaudrey',
#  'Associate Professor': 'mistyray',
#  'Operational investment banker': 'jsmith',
#  'Exhibitions officer, museum/gallery': 'kellymorris',
#  'Applications developer': 'morganross',
#  'Intelligence analyst': 'lmathews',
#  'Civil Service administrator': 'pjohnson',
#  'Pharmacologist': 'hallheather',
#  'Health promotion specialist': 'karen49',
#  'Personal assistant': 'kathryn70',
#  'Field trials officer': 'carlos61',
#  'Advertising account executive': 'williamsjustin',
#  'General practice doctor': 'simpsonamber',
#  'Writer': 'evanscasey',
#  'Doctor, general practice': 'medinadean',
#  'Warden/ranger': 'teresa76',
#  'Speech and language therapist': 'adamsrobert',
#  'Data scientist': 'rwilliams',
#  'Commercial horticulturist': 'hwright',
#  'Naval architect': 'jose78',
#  'Technical brewer': 'wagnermichael',
#  'Engineer, materials': 'lambertjimmy',
#  'Herpetologist': 'tpratt',
#  'Research scientist (medical)': 'marygreen',
#  'Pilot, airline': 'laurie16',
#  'Veterinary surgeon': 'reynoldspatricia',
#  'Museum education officer': 'wandamcguire',
#  'Production assistant, television': 'trevinodawn',
#  'Therapist, art': 'jessicanewton',
#  'Editorial assistant': 'danielsmith',
#  'Horticulturist, commercial': 'smolina',
#  'Engineer, automotive': 'josephberger',
#  'Food technologist': 'christina47',
#  'Agricultural consultant': 'nelsonrachel',
#  'Immigration officer': 'stricklanddevon',
#  'Accountant, chartered certified': 'sheila97',
#  'Engineer, communications': 'pricejames',
#  'Surveyor, building control': 'john33',
#  'Herbalist': 'brittany31',
#  'Systems analyst': 'monique00',
#  'Therapist, music': 'adamhill',
#  'Production manager': 'kblack',
#  'Designer, fashion/clothing': 'shaun03',
#  'Chartered loss adjuster': 'wandamcguire',
#  'Engineer, agricultural': 'njones',
#  'Race relations officer': 'stevenspencer',
#  'Engineer, manufacturing systems': 'christina47',
#  'Lobbyist': 'gonzalezshawn',
#  'Community arts worker': 'christinabryant',
#  'Medical physicist': 'brendahill',
#  'Leisure centre manager': 'progers',
#  'Dancer': 'fnicholson',
#  'Teacher, adult education': 'leebarbara',
#  'Community education officer': 'glennroberson',
#  'Accounting technician': 'bruce73',
#  'IT consultant': 'edward83',
#  'Scientist, biomedical': 'cbishop',
#  'Plant breeder/geneticist': 'mary70',
#  'Geophysical data processor': 'oyoung',
#  'Armed forces technical officer': 'medinakenneth',
#  'Teacher, primary school': 'jessicali',
#  'Freight forwarder': 'rlong',
#  'Psychiatrist': 'ganderson',
#  'Economist': 'monique00',
#  'Quarry manager': 'kevin60',
#  'Therapist, nutritional': 'douglashendricks',
#  'Production assistant, radio': 'hickssonya',
#  'Web designer': 'traceyleblanc',
#  'Ambulance person': 'nicolewhite',
#  'Chartered legal executive (England and Wales)': 'lambertjimmy',
#  'Field seismologist': 'rebecca50',
#  'Scientist, clinical (histocompatibility and immunogenetics)': 'youngheidi',
#  'Prison officer': 'rleblanc',
#  'Engineer, electrical': 'traciewells',
#  'Forensic scientist': 'mdavis',
#  'English as a second language teacher': 'jillibarra',
#  'Psychologist, occupational': 'sandra18',
#  'Arts administrator': 'thomasreginald',
#  'Ergonomist': 'nicole93',
#  'Passenger transport manager': 'kathleenbarnett',
#  'Psychologist, forensic': 'timothyknight',
#  'Sales promotion account executive': 'morgan82',
#  'Make': 'brownlaura',
#  'Science writer': 'urhodes',
#  'Administrator, Civil Service': 'lee99',
#  'Industrial/product designer': 'mistyray',
#  'Community pharmacist': 'rleblanc',
#  'Dramatherapist': 'zbrown',
#  'Pharmacist, community': 'tina65',
#  'Engineer, civil (contracting)': 'jeffreysmith',
#  'Trade union research officer': 'gpearson',
#  'Fish farm manager': 'ssims',
#  'Research scientist (physical sciences)': 'mark71',
#  'Solicitor': 'clintonjones',
#  'Actor': 'john33',
#  'Music tutor': 'fergusonjerry',
#  'Engineer, production': 'wjones',
#  'Runner, broadcasting/film/video': 'cindy77',
#  'Medical laboratory scientific officer': 'adam63',
#  'Manufacturing engineer': 'darlene15',
#  'Therapist, occupational': 'johnleonard',
#  'Ranger/warden': 'rrangel'}

# %% [markdown]
# ### XML

# %% [markdown]
# 3.1 По данным файла `steps_sample.xml` сформируйте словарь с шагами по каждому рецепту вида `{id_рецепта: ["шаг1", "шаг2"]}`. Сохраните этот словарь в файл `steps_sample.json`

# %%
import xmltodict
import pprint
import json


with open('steps_sample.xml') as fd: 
    doc = xmltodict.parse(fd.read())

pp = pprint.PrettyPrinter(indent = 4)
pp.pprint(json.dumps(doc))
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# 'a separate bowl , place onions and celery , pepper , salt , seasoning salt , '
#  'sour cream , mayonnaise and red wine vinegar", "mix well", "add mayonnaise / '
#  'vegetable mixture to potatoes and mix well", "chill before serving"]}}, '
#  '{"id": "172427", "steps": {"step": ["preheat oven to 350", "spray baking '
#  'dish lightly with cooking spray", "mix in baking dish the whole berry '
#  'cranberry sauce & onion soup mix", "place pork in baking dish and spoon some '
#  'of the mixture over the top", {"@has_minutes": "1", "#text": "cover with '
#  'foil and bake 30 minutes"}, {"@has_minutes": "1", "#text": "remove foil , '
#  'turn chops and continue to bake uncovered additional 20-30 minutes or until '
#  'pork is done & tender"}, "serve spooning sauce over pork", "to freeze: place '
#  'chops in a freezer bag and seal", "mix together the soup and cranberry '
#  'sauce", "place in a second bag and seal", "place both bags into a larger '
#  'freezer bag", "seal , label and freeze", "to serve: thaw overnight in '
#  'fridge", "proceed with cooking directions"]}}, {"id": "140564", "steps": '
#  '{"step": ["cook bacon separately and set aside", "mix together turkey , '
#  'onion , soy , ketchup , garlic , pepper and cheese", "mix together and form '
#  'into patties", "grill or fry in pan", "put on bun add 1 strip bacon and '
#  'slice of tomato"]}}, {"id": "63599", "steps": {"step": ["bake fries '
#  'according to package directions", "transfer to a 10 inch skillet", "top with '
#  'bacon , onions , olives , tomatoes , salsa& cheeses", {"@has_degrees": "1", '
#  '"@has_minutes": "1", "#text": "return to the oven at 400 degrees for 5 '
#  'minutes or until cheese is melted"}, "serve with sour cream"]}}, {"id": '
#  '"219121", "steps": {"step": ["preheat waffle maker and spray surface with '
#  'non-stick cooking spray", "in large bowl , whisk eggs until frothy , then '
#  'add remaining ingredients and whisk until well mixed", "dip 1 slice of bread '
#  'into mixture and turn to cover both sides", "place in waffle maker and cook '
#  'until golden brown", "top with syrup or powdered sugar"]}}, {"id": "291316", '
#  '"steps": {"step": ["preheat a waffle iron", "place 2 slices of the bread on '
#  'a flat work surface", "spread one side of each slice with the emeril\'s '
#  'russian dressing", "on 1 slice of bread , stack half of the cheese , ham , '
#  'and corned beef in layers", "top with the other slice of bread , dressing '
#  'side down , and push together to form a sandwich", "spread softened butter '
#  'on both sides of the sandwich and place in the hot waffle iron", '
#  '{"@has_minutes": "1", "#text": "cook until the sandwich is golden brown on '
#  'the outside and the cheese is melted , about 5 minutes"}, "remove from the '
#  'grill and cut into quarters", "serve immediately with the sauerkraut , and '
#  'repeat with the remaining sandwich"]}}, {"id": "366740", "steps": {"step": '
#  '["in a large mixing bowl , stir together all the dry ingredients", "in a '
#  'second bowl , combine the wet ingredients", "separate the eggs", "lightly '
#  'beat the yolks before stirring them into the wet ingredients bowl", "reserve '
#  'the egg whites in a small bowl", "combine the wet and dry ingredients , '
#  'mixinging just until blended", "don\'t worry if the batter is a little '
#  'lumpy", "cover the bowl loosely and set aside", "beat the egg whites until '
#  'stiff peaks form", "gently , gently , gently , fold the egg whites into the '
#  'waffle batter", "this is what will produce the nice , crispy outside of your '
#  'waffles", "ladle the batter into a hot waffle iron and bake until they stop '
#  'steaming"]}}, {"id": "317317", "steps": {"step": ["place the hash browns in '
#  'a 7-inch pie plate coated with nonstick cooking spray", "in a small bowl , '
#  'combine the cream cheese , 2 tablespoons milk , onion , salt , and pepper", '
#  '"spread over potatoes", "cut sausage links in half lengthwise", "arrange '
#  'over potatoes in a spoke-like fashion", "in a small bowl , whisk the biscuit '
#  'mix , egg , nutmeg , and remaining milk until smooth", "pour between '
#  'sausages", "sprinkle with paprika", {"@has_minutes": "1", "#text": "bake at '
#  '400 for 25-30 minutes or until golden brown and filling is bubbly"}]}}, '
#  '{"id": "209175", "steps": {"step": ["preheat oven to 400f", "bring a large '
#  'pot of salted water to a boil", {"@has_minutes": "1", "#text": "boil pasta , '
#  'uncovered , for about 5 to 6 minutes , stirring occasionally , until the '
#  'pasta is al dente"}, "remove from heat , drain the pasta , and then return '
#  'the pasta to the pot", "meanwhile , heat the olive oil over medium heat in a '
#  'heavy skillet", {"@has_minutes": "1", "#text": "add the onion and saut until '
#  'soft and lightly brown , about 3 minutes"}, "remove from heat , and add the '
#  'onion to the pasta", "cook bacon strips in the same skillet until crisp , '
#  'set on a paper towel to drain", "once cool , crumble into small pieces , and '
#  'add to the pasta", "add the chicken broth , peas , ricotta cheese , egg , '
#  'basil , parsley , parmesan cheese and salt and pepper to the pasta , and '
#  'stir to combine", "transfer pasta to a 7x11 casserole dish", '
#  '{"@has_minutes": "1", "#text": "sprinkle fontina cheese and bread crumbs on '
#  'top and bake in oven for 10 to 15 minutes until the cheese has melted and '
#  'the bread crumbs have turned a golden brown"}]}}, {"id": "237468", "steps": '
#  '{"step": ["in large nonstick skillet over medium-high heat , add beef , '
#  'onions and garlic", {"@has_minutes": "1", "#text": "cook , breaking up with '
#  'sppon , until no longer pink , about 5 minutes"}, "pour off drippings", '
#  '"stir in spaghetti sauce , diced tomatoes , pasta and 3 / 4 cup of water", '
#  '"spread mixture level", "bring to simmer", {"@has_minutes": "1", "#text": '
#  '"cook , uncovered , until pasta is just tender , about 14 minutes"}, '
#  '"sprinkle on mozzarella , then parmesan", {"@has_minutes": "1", "#text": '
#  '"cover and let stand until cheese is melted , about 5 minutes"}, "serve '
#  'immediately"]}}, {"id": "333216", "steps": {"step": ["soak wakame in water '
#  'until soft and salt is removed", "drain and cut into bite size pieces", "i '
#  'usually do this with scissor", "with a bit of salt , rub the okra to remove '
#  'the fuzziness", {"@has_minutes": "1", "#text": "parboil okra for about 1 - 2 '
#  'minutes in hot water"}, "plunge in chilled water to cool down quickly", '
#  '"slice okra into 1 / 4 inch slices", "combine sugar , soy sauce , rice '
#  'vinegar , water and salt in a small bowl", "place wakame , okra , and ginger '
#  'in the bowl and combine well", "chill before serving", {"@has_hours": "1", '
#  '"#text": "best served immediately or within 6 hours"}]}}, {"id": "167888", '
#  '"steps": {"step": ["place hash brown patties in 13x9 greased casserole", '
#  '"sprinkle with cheese , and ham", "in a bowl , beat eggs , half-and-half , '
#  'salt and mustard well", "pour over ham", "sprinkle with pepper and bacon if '
#  'desired", "cover", "at this point it can be refrigerated and baked in the '
#  'morning", {"@has_minutes": "1", "#text": "bake at 350f for 45 minutes '
#  'covered ,"}, {"@has_minutes": "1", "#text": "uncover and bake additional 15 '
#  'minutes or longer until edges are golden brown and knife inserted in center '
#  'comes out clean"}, "cool slightly and cut around the hash brown patties to '
#  'serve"]}}, {"id": "203818", "steps": {"step": ["prepare waffles in toaster '
#  'according to package directions", "in a small bowl , combine jam , cream '
#  'cheese and crumbled bacon", "spread one side of a waffle with cream cheese '
#  'mixture", "top with some of the sliced strawberries and another waffle to '
#  'make a sandwich", "serve immediately", "for a slumber party , make a batch '
#  'using mini waffles", "you can substitute kiwi , banana , etc for the '
#  'strawberries", "maybe drizzle a little chocolate syrup before sandwiching -- '
#  'be creative and have fun !"]}}, {"id": "179643", "steps": {"step": '
#  '[{"@has_hours": "1", "#text": "soak a 10 inch long , 6\\" to 8\\" wide , '
#  'construction grade cedar plank 3 / 4\\" thick , in water for at least 24 '
#  'hours before making the recipe"}, "make sure you keep the wood submerged by '
#  'weighing it down with cans", "start your barbecue and heat it to high", '
#  '"place salmon in shallow , non-metallic dish", {"@has_minutes": "1", '
#  '"#text": "combine all but the lemon juice and pour on salmon , turning to '
#  'coat and let sit at least 20 minutes"}, "put the plank on the bbq and '
#  'sprinkle with a little coarse salt", {"@has_minutes": "1", "#text": "close '
#  'the cover for a couple of minutes or just until the top of the plank is '
#  'nearly dry"}, "place the filets on top of the plank", "if your bbq has two '
#  'burners , turn off the one beneath the wood", "if not , turn the heat to the '
#  'lowest setting", {"@has_minutes": "1", "#text": "close the cover and cook '
#  'for about 10- 12 minutes or until nearly cooked all the way through"}, '
#  '"don\'t overcook", "once salmon is planked and cooking , pour leftover '
#  'marinade into small saucepan , squeeze in lemon and simmer until reduced to '
#  'glaze consistency ,", "basically as long as the salmon cooks", "you now have '
#  'a fab sauce to drizzle on the salmon before serving ! bon apetit !"]}}, '
#  '{"id": "246665", "steps": {"step": ["use a 50ml sherry glass", "sambuca '
#  'first , then layer with espresso and finish off with a top layer of '
#  'cream"]}}, {"id": "78104", "steps": {"step": ["for the pumpkin using a small '
#  'pie pumpkin , cut pie pumpkin in half", {"@has_degrees": "1", "@has_hours": '
#  '"1", "#text": "remove seeds and bake covered with foil about an hour at '
#  '350-375 degrees"}, "remove pumpkin and mash", "mix all ingredients until '
#  'smooth", {"@has_degrees": "1", "@has_minutes": "1", "#text": "pour into '
#  'crust and bake 15 minutes at 450 degrees then reduce heat and bake 45 min"}, '
#  '{"@has_degrees": "1", "#text": "at 325 degrees"}]}}, {"id": "79948", '
#  '"steps": {"step": {"@has_hours": "1", "#text": "throw this all together in a '
#  'large dutch oven and cook , covered in slow oven , 250 , for 5 hours"}}}, '
#  '{"id": "126729", "steps": {"step": ["in medium bowl , combine all '
#  'ingredients except bread and lettuce , mix well", "top each with lettuce '
#  'leaf", "cover with remaining bread slices"]}}, {"id": "366756", "steps": '
#  '{"step": ["mix the vermouth , gin , campari , orange liqueur and orange '
#  'juice well and pour into a highball glass full of ice cubes", "top with a '
#  'splash of club soda if you like and decorate with a twist of orange '
#  'peel"]}}, {"id": "290497", "steps": {"step": [{"@has_degrees": "1", "#text": '
#  '"preheat the oven to 400 degrees"}, "in a small bowl , combine all the '
#  'ingredients except the turkey legs", "mix well", "place the turkey legs on a '
#  'rack in a roasting pan and brush evenly with the oil mixture", '
#  '{"@has_hours": "1", "#text": "bake for 1 1 / 4 to 1 1 / 2 hours , or until '
#  'the skin is golden brown and no pink remains , basting occasionally"}]}}, '
#  '{"id": "192656", "steps": {"step": ["peel and cut the onions in half and '
#  'then quarter the halves", "slice the quarters in food processor fitted with '
#  'slicing disc", {"@has_degrees": "1", "#text": "preheat oven to 350 '
#  'degrees"}, "melt 1 / 4 cup butter in a large skillet and saute onions over '
#  'medium heat until tender", "place half the onion mixture into a 1 1 / '
#  '2-quart oven-proof casserole", "sprinkle 1 cup of swiss cheese and 1 / 2 cup '
#  'cracker crumbs over onions", "repeat layers of onions and cheese", "beat '
#  'eggs with the half-and-half , salt and pepper", "pour evenly over layered '
#  'contents of casserole", "melt 2 tablespoons butter in skillet and stir in '
#  'remaining cracker crumbs", "lightly brown over medium heat", "sprinkle '
#  'browned crumbs over casserole", {"@has_minutes": "1", "#text": "bake for 25 '
#  'minutes"}]}}, {"id": "354241", "steps": {"step": ["toss the shrimp in a '
#  'medium bowl with the essence", "place the olive oil and 2 tablespoons of the '
#  'butter in a large skillet over high heat", {"@has_minutes": "1", "#text": '
#  '"add garlic and shallot and saut for 1 minute"}, {"@has_minutes": "1", '
#  '"#text": "add shrimp and saut for 2 minutes or until the shrimp is just '
#  'cooked through"}, {"@has_minutes": "1", "#text": "add the wine , lemon juice '
#  ', and remaining 2 tablespoons of the butter to the skillet and cook for 1 1 '
#  '/ 2 minutes"}, "add the pasta and toss until noodles are coated with sauce", '
#  '"garnish with scallion", "serve immediately"]}}, {"id": "117369", "steps": '
#  '{"step": ["cook shallots in 1 tbsp butter in skillet till soft", "add '
#  'mushrooms , cook till all liquid from the mushrooms is evaporated", "add '
#  'thyme , stock & simmer till mixture is almost dry", "remove from heat , stir '
#  'in walnuts , sour cream , mustard , salt & pepper to taste", "melt remaining '
#  'butter in saucepan", "preheat oven to 400", "roll bread one slice at a time '
#  'with a rolling pin till paper thin", "mound 1 tbsp of mushroom mixture in '
#  'the center of bread slice , brush edges with melted butter , fold over into '
#  'a triange and crimp edges", "repeat with remining bread & mushroom mix", '
#  '"take care bread does not dry out", "i use the cheapo white square stuff it '
#  'gives a good seal when fresh", "you can tightly wrap triangles at this point '
#  'and refridge till ready to use", "i have done this over night", "again the '
#  'trick is to not let them dry out", {"@has_minutes": "1", "#text": "place '
#  'triangles on cookie sheet , brush with melted butter and bake for 10 minutes '
#  'or until golden brown"}]}}, {"id": "301792", "steps": {"step": ["in a wooden '
#  'bowl or food processor , mash walnuts and pine nuts until they have a grainy '
#  'consistency", "add all remaining ingredients except cream and mix '
#  'thoroughly", "the sauce may be prepared ahead of time to this point", "add '
#  'cream just before serving", "do not heat sauce , but serve over hot '
#  'pasta"]}}, {"id": "256561", "steps": {"step": ["combine the water , sugar , '
#  'and raisins in a 2-litre / quart saucepan", "place over moderate heat , '
#  'stirring to dissolve the sugar", "bring to the boil , then reduce the heat '
#  'to very low and cover with a tight-fitting lid", "place the butter in a 2- '
#  'or 3-litre / quart non-stick saucepan and over fairly low heat , stirring '
#  'occasionally , melt the butter without scorching", "add the semolina", '
#  '"slowly and rhythmically stir-fry the grains until they darken to a tan '
#  'colour and become aromatic", "add the walnut pieces about half-way through '
#  'the roasting", "stirring more carefully , raise the heat under the grains", '
#  '"raise the heat under the sugar water and bring the syrup to a rolling '
#  'boil", "remove the saucepan of semolina and butter from the heat , slowly '
#  'pouring the hot syrup into the semolina , stirring steadily", "the grains '
#  'may at first splutter , but will quickly cease as the liquid is absorbed", '
#  '"return the pan to the stove and stir steadily over low heat until the '
#  'grains fully absorb the liquid , start to form into a pudding-like '
#  'consistency , and pull away from the sides of the pan", {"@has_minutes": '
#  '"1", "#text": "place a tight-fitting lid on the saucepan and cook over the '
#  'lowest possible heat for 5 minutes"}, {"@has_minutes": "1", "#text": "turn '
#  'off the heat , allow the halava to steam , covered , for an additional 5 '
#  'minutes"}, "serve hot in dessert bowls as it is , or with cream or hot '
#  'custard"]}}, {"id": "171293", "steps": {"step": [{"@has_minutes": "1", '
#  '"#text": "in a large saucepan , saute onion and celery in butter for 3-4 '
#  'minutes or until tender"}, "add the water , cider , salt and cinnamon and '
#  'bring to a boil", "stir in the rice , apple and walnuts", {"@has_minutes": '
#  '"1", "#text": "cover and remove from the heat , let stand for 5 minutes"}, '
#  '"fluff with a fork"]}}, {"id": "487914", "steps": {"step": ["preheat oven to '
#  '350f and spray a 9 x 5 x 3 inch loaf pan with nonstick cooking spray", '
#  '"whisk together sugar , milk , oil , vanilla , yogurt , egg and lemon zest '
#  'in a large bowl", "stir together dry ingredients an 3 / 4 cup walnuts and '
#  'add to bowl , stirring just until dry ingredients are incorporarted", '
#  '"carefully fold in blackberries and spead into prepared pan", "sprinkle with '
#  'remaining walnuts", {"@has_hours": "1", "@has_minutes": "1", "#text": "bake '
#  'for 1 hour and 20 minutes or until a toothpick inserted into the center '
#  'comes out clean"}]}}, {"id": "3189", "steps": {"step": ["lightly grease '
#  'sides of 8 or 9-inch springform pan", "combine crust ingredients", "mix '
#  'well", "press evenly over bottom of pan", "chill while preparing filling", '
#  '"in bowl of electric mixer , combine ricotta cheese , brown sugar , cocoa , '
#  'half-and-half , flour , vanilla and salt", "beat until smooth", "add eggs , '
#  'one at a time", "beat until smooth", "stir in walnuts", "pour batter over '
#  'crust", {"@has_hours": "1", "@has_minutes": "1", "#text": "bake at 350 f 1 '
#  'hour and 10 minutes or until center is just set"}, "turn off oven", '
#  '{"@has_minutes": "1", "#text": "cool in oven with door propped open 30 '
#  'minutes"}, "remove to wire cooling rack", "loosen cake from rim of pan with '
#  'metal spatula", "cool completely", {"@has_hours": "1", "#text": "chill at '
#  'least 4 hours"}, "if desired , sift confectioners sugar over cheesecake '
#  'immediately before serving , or ice with suggested icing and garnish with '
#  'chocolate curls and whole walnuts"]}}, {"id": "385325", "steps": {"step": '
#  '["place almond meal , cacao powder , and salt in a large mixing bowl", "mix '
#  'well", "add dates and honey , and mix well", "add crushed walnuts and mix", '
#  '"line a loaf or square pan with parchment paper or plastic wrap", "press '
#  'mixture into bottom of pan", "enjoy immediately , or chill for a firmer '
#  'texture", "per serving: 109 cal , 49% fat cal , 7g fat , 1g sat fat , 0mg '
#  'chol , 3g protein , 13g carb , 3g fiber , 28mg sodium"]}}, {"id": "386714", '
#  '"steps": {"step": [{"@has_degrees": "1", "#text": "preheat oven to 375 '
#  'degrees"}, "put the walnuts in a food processor and chop finely", "remove '
#  'and set aside", "add flour plus the extra 1 tbs of flour , salt & pepper to '
#  'the processor bowl", "cut the butter into small pieces and add to the flour '
#  'mixture", "mix in short bursts until the mixture resembles fine '
#  'breadcrumbs", "coarsely grate in cheese , add the reserved walnuts and mix '
#  'quickly to form a dough", "turn mixture on to a lightly floured surface and '
#  'roll out thinly", "using a 2 1 / 2 in round cookie cutter cut the dough into '
#  'rounds and place on baking trays", "brush the tops with beaten egg", '
#  '{"@has_degrees": "1", "@has_minutes": "1", "#text": "bake in preheated 375 '
#  'degree oven for about 10 minutes until golden"}, "cool and store in airtight '
#  'container"]}}, {"id": "43150", "steps": {"step": ["add marinade ingredients '
#  'to chicken and mix well", {"@has_minutes": "1", "#text": "marinate for 10 '
#  'minutes"}, "while marinating chicken mix together the sauce ingredients", '
#  '"set aside", "heat wok on high with the oil", "add the garlic and stir for a '
#  'few seconds", "add the chicken and cook to 80% done", "reduce heat to medium '
#  'and add the sauce , giving it a good stir", {"@has_minutes": "1", "#text": '
#  '"cook for 1 minute"}, "add the walnuts and sesame oil", {"@has_minutes": '
#  '"1", "#text": "cook for 1 minute more"}, "remove from heat and serve with '
#  'rice and veggies"]}}, {"id": "263428", "steps": {"step": ["salt and pepper '
#  'chicken", "beat 2 egg whites", "dip chicken into egg whites , allow excess '
#  'to drip off , then roll in walnuts", "place in a buttered baking dish", '
#  '{"@has_minutes": "1", "#text": "bake at 350f for 30-45 minutes , until '
#  'chicken is cooked through"}, "while chicken is cooking , melt butter and '
#  'stir in flour", "add chicken broth , salt , and white pepper", "cook , '
#  'stirring constantly , until mixture boils and begins to thicken", "beat egg '
#  'yolks together with whole eggs", "stir the hot sauce into the eggs , '
#  'stirring quickly", "return sauce to pan and cook over low heat until '
#  'thickened , stirring constantly", "remove from heat and add grated lime peel '
#  'and lime juice", "stir until well blended", "to serve , top cooked chicken '
#  'with lime sauce"]}}, {"id": "50066", "steps": {"step": ["in a bowl , beat '
#  'cream cheese , butter , and sugar until smooth and creamy", "add eggs and '
#  'vanilla", "beat until light and fluffy", "add milk and stir until blended", '
#  '"mix together flour and next 3 ingredients in a bowl", "add to creamed '
#  'mixture", "beat on low until mixed", "stir in walnuts", "pour batter into a '
#  'greased 13x9 inch baking pan", "to make topping , mix together flour , sugar '
#  ', and cinnamon", "cut in butter with a pastry blender until mixture '
#  'resembles coarse crumbs", "stir in walnuts", "sprinkle mixture over batter", '
#  '{"@has_degrees": "1", "@has_minutes": "1", "#text": "bake at 350 degrees for '
#  '40 minutes or until a pick comes out clean"}, "best served warm"]}}, {"id": '
#  '"428200", "steps": {"step": [{"@has_degrees": "1", "#text": "preheat oven to '
#  '350 degrees"}, "butter and flour 8 x 8 inch baking pan", "in a large mixing '
#  'bowl", "mix graham crackers crumbs , sugar and baking powder", "beat egg '
#  'yolks lightly , add to the dry ingredients and stir", "stir in walnuts and '
#  'vanilla", "mix well", "beat egg whites in a separate bowl with a pinch of '
#  'salt until stiff", "gently fold into the graham cracker mixture", "pour into '
#  'baking pan", {"@has_minutes": "1", "#text": "bake untill golden brown , '
#  'about 25 minutes"}, "let cool in pan , cut into bars", "serve with ice cream '
#  'or whipped cream on top"]}}, {"id": "73644", "steps": {"step": ["butter an '
#  '8-inch square glass-baking dish", "heat sugar , corn syrup , water and salt '
#  'over low heat in a heavy 2-quart saucepan until sugar is dissolved , '
#  'stirring occasionally", "increase heat to high and bring to a boil", "boil , '
#  'without stirring , until syrup reaches 265 on a candy thermometer", "just '
#  'before syrup reaches 265 , beat egg whites in a medium bowl of an electric '
#  'mixer on high speed just until stiff peaks form", "in a very slow steady '
#  'stream , beat syrup into whites", "beat in vanilla", {"@has_minutes": "1", '
#  '"#text": "continue beating about 6 minutes , or until mixture loses it\'s '
#  'gloss"}, "fold in nuts with a rubber spatula", "pour candy into baking dish '
#  'and spread evenly with a rubber spatula", "let cool to room temperature", '
#  '"cut candy into 1-inch squares"]}}, {"id": "293067", "steps": {"step": '
#  '["line a square baking pan with foil", "combine sugar , milk , salt and '
#  'butter in pan and bring to a boil over med", {"@has_minutes": "1", "#text": '
#  '"heat for 4 minutes and remove from heat"}, "make sure not to let it burn by '
#  'stirring constantly", "do not leave it !", "once boiling , stir nuts , '
#  'marshmallows and vanilla", "stir until marshmallows are melted and pour into '
#  'pan", {"@has_hours": "1", "#text": "refridgerate until firm (a couple '
#  'hours"}, "once cool , lift the whole thing out by pulling up on the foil", '
#  '"cut into pieces"]}}, {"id": "156559", "steps": {"step": ["cook pasta '
#  'according to package directions", {"@has_minutes": "1", "#text": "meanwhile '
#  ', in a large skillet , saute garlic in oil for 1 minute"}, {"@has_minutes": '
#  '"1", "#text": "add walnuts , saute for 2 minutes"}, "stir in ham", '
#  '{"@has_minutes": "1", "#text": "cook until heated through , about 2 '
#  'minutes"}, "drain pasta", "toss with ham mixture", "sprinkle with parmesan '
#  'and parsley"]}}, {"id": "265656", "steps": {"step": ["make the dough - night '
#  'before", "mix milk , sugar and yeast", "let stand until it rises and '
#  'thickens", "cut butter into 2 1 / 4 cups flour with mixer or pastry '
#  'blender", "make well and add egg yolks and yeast mixture", "mix well and '
#  'knead on floured board until smooth and not sticky", "divide dough evenly '
#  'into 6 balls", "place in floured 9 x 12 pan , cover and refrigerate '
#  'overnight", "they should increase slightly in size", "make the nut filling - '
#  'night before", "beat the egg whites until stiff", "add the nuts , 3 / 4 cups '
#  'sugar and lemon juice", "mix well", "press the nut filling into a square pan '
#  ', cover and refrigerate overnight", "getting ready - next day", '
#  '{"@has_hours": "1", "#text": "take the dough balls out of the refrigerator '
#  'at least 4 hours before you will begin rolling them out"}, "take the nut '
#  'filling out just before rolling the dough out", "cut the nut filling into 48 '
#  'portions like you are cutting up bar cookies", "mix together remaining 1 cup '
#  'of sugar and 2 tablespoons flour", "preheat oven to 350f", "sprinkle work '
#  'surface liberally with sugar / flour mixture to prevent dough from '
#  'sticking", "roll one dough out to 10 inch circle", "using pizza cutter or '
#  'knife , cut each circle into 8 slices", "put one nut portion at the large '
#  'end of a slice", "roll from large end to point , tucking in sides , forming '
#  'a crescent", "trt to keep them pinched close so the filling doesn\'t leak '
#  'out during baking", "place on ungreased cookie sheet with point on bottom", '
#  '"you can probably fit at least 16 cookies per tray", "continue until all '
#  'dough is rolled and filled using plenty of sugar / flour mixture to prevent '
#  'sticking", {"@has_degrees": "1", "@has_minutes": "1", "#text": "bake at 350 '
#  'degrees for 20 minutes or until dough is golden"}, "remove from oven and '
#  'remove cookies from tray immediately to prevent sticking", "cool on wire '
#  'rack"]}}, {"id": "146145", "steps": {"step": ["place walnuts , garlic , '
#  'vinegar , lemon juice , honey , dill , pepper , salt and orange juice in a '
#  'blender container", "process until smooth", "with blender running , slowly '
#  'pour the oil through hole in lid", "process until emulsified", "serve over '
#  'salad", "enjoy !"]}}, {"id": "42892", "steps": {"step": ["line an 8 inch '
#  'square pan with foil , letting foil extend above 2 sides", "grease lightly", '
#  '"spread nuts in a 9 inch microwave safe pie plate", {"@has_minutes": "1", '
#  '"#text": "microwave uncovered on high 6 to 7 minutes , stirring 3 times , '
#  'until lightly toasted"}, "melt butter in a 3 quart microwave safe bowl", '
#  '"stir in sugar and milk until blended", {"@has_minutes": "1", "#text": '
#  '"microwave uncovered on high 7 to 9 minutes , stirring 4 times , until sugar '
#  'has completely dissolved and mixture has thickened and is a medium caramel '
#  'color"}, "using potholders , move bowl to heatproof surface", "add vanilla", '
#  '{"@has_minutes": "1", "#text": "beat with an electric mixer 3 to 4 minutes '
#  'until smooth and shiny"}, {"@has_minutes": "1", "#text": "add walnuts and '
#  'beat on low sped 1 minute to distribute evenly"}, "spread in prepared pan", '
#  '{"@has_hours": "1", "#text": "cool , then cover and refrigerate until firm , '
#  '2 to 3 hours"}, "holding foil ends , carefully lift candy to cutting board", '
#  '"peel off foil", "cut candy in 1 inch squares", "store tightly covered in a '
#  'cool place"]}}, {"id": "173200", "steps": {"step": ["preheat oven to 400f", '
#  '"in a small bowl , beat eggs lightly", "stir in sugar , vanilla , syrup , '
#  'butter , and nuts", "spread mixture evenly into bottom pie crust", "place '
#  'top crust over filling", "fold top crust under bottom crust", "flute edge as '
#  'desired", "brush top pastry with beaten egg yolk", {"@has_minutes": "1", '
#  '"#text": "bake 10 minutes"}, "reduce heat to 350f", {"@has_minutes": "1", '
#  '"#text": "bake 30 minutes longer"}]}}, {"id": "135454", "steps": {"step": '
#  '[{"@has_degrees": "1", "#text": "heat oven to 350 degrees"}, "mix flour with '
#  'baking powder", "in a large bowl , with mixer at medium speed , mix butter '
#  'and sugar", "then add eggs and beat mixture until light and fluffy", "at low '
#  'speed beat in flour mixture alternately with milk , beating well after each '
#  'addition", "stir in grated orange peel and walnuts", "lightly grease and '
#  'flour a 13x9 pan", "pour butter into pan", {"@has_hours": "1", "#text": '
#  '"bake in oven for about 1 hour"}, "cool", {"@has_minutes": "1", "#text": '
#  '"meanwhile boil for 5 minutes the sugar , water and lemon juice , pour hot '
#  'syrup over nut pie"}, "cool and cut into squares"]}}, {"id": "201166", '
#  '"steps": {"step": ["cream butter and shortening thoroughly", "add sugar , 1 '
#  '/ 2 cup at a time", "beat until light", "add eggs , one at a time , beating '
#  'after each addition", "add 2 cups flour alternately with milk containing '
#  'flavoring", "add the last 1 cup flour containing salt and baking powder", '
#  '"stir in 1 cup finely chopped walnuts", "the batter will be thick and '
#  'fluffy", "spoon into tube pan , which has been lightly greased and floured", '
#  '"place the cake in cold oven on middle shelf", "turn oven to 350f", '
#  '{"@has_hours": "1", "#text": "don\'t open door for 1 1 / 4 hours"}, "allow '
#  'cake to cool in pan on wire rack"]}}, {"id": "136325", "steps": {"step": '
#  '["process the walnuts , garlic , breadcrumbs and 1 / 2 teaspoon sea salt in '
#  'a food processor until finely chopped", "add saba and 2 tablespoons warm '
#  'water and process until the mixture forms a smooth", "paste , then , with '
#  'the motor running , gradually add the olive oil until all the ingredients '
#  'are well-combined", "season to taste with freshly ground black pepper , '
#  'transfer to a suitable serving bowl and serve with walnut bread or with your '
#  'choice of crackers , breads and vegetable sticks", "it is similar in flavour '
#  'to vincotto which makes a good substitute and is produced in a similar '
#  'manner , but from different grape varieties"]}}, {"id": "192114", "steps": '
#  '{"step": ["to make topping: in a small bowl with your finger", "chill '
#  'topping , covered", "to make filling: peel and core apples", "cut apples '
#  'into 1 / 2-inch wedges and in a bowl toss with remaining filling ingredients '
#  'to coat", "preheat oven to 350f unfold defrosted , store-bought dough into a '
#  'well-seasoned 10-inch cast-iron skillet or 10-inch deep-dish pie plate , '
#  'easing to fit", {"@has_hours": "1", "#text": "spoon filling into shell , '
#  'bake pie in middle of oven for 1 hour and remove from oven"}, "crumble '
#  'topping over center of pie , breaking up any large chunks", {"@has_minutes": '
#  '"1", "#text": "bake pie in middle of oven 30 minutes more , or until crust '
#  'is golden and filling is bubbling"}, "cool pie on a rack and serve warm or '
#  'at room temperature with vanilla ice cream or sour cream ice cream"]}}, '
#  '{"id": "131930", "steps": {"step": ["preheat oven to 375f", "grease and '
#  'flour round layer cake pan or square 8\\" x 8\\" or 9\\" x 9\\" pan", "blend '
#  'first seven ingredients", "beat vigorously 30 seconds", "mix brown sugar , '
#  'cinnamon , nuts and melted butter in a small bowl", "pour half cake batter '
#  'into pan", "sprinkle half of brown sugar mixture over batter", "pour '
#  'remaining cake batter in pan", "top with remaining brown sugar mixture", '
#  '{"@has_minutes": "1", "#text": "bake 25-30 minutes or until toothpick '
#  'inserted in center comes out clean"}]}}, {"id": "380053", "steps": {"step": '
#  '["to make cheeze:", "place garlic and salt in a food processor", "process '
#  'into small pieces", "add cashews and process into paste", "add lemon juice , '
#  'cilantro , and water and process to mix well", "set aside", "makes 1 cup", '
#  '"to make meat:", "place walnuts , cumin , coriander , liquid aminos , and '
#  'salt in a food processor", "process into small pieces until the mixture '
#  'looks like ground meat", "be careful not to overprocess , it will turn into '
#  'butter", "makes 1 cup", "scoop 2 tablespoons cashew mixture down the inside '
#  'spine of each romaine leaf", "sprinkle with 2 tablespoons walnut mixture", '
#  '"add salsa and avocado slices", "wrap and serve", "enjoy !"]}}, {"id": '
#  '"138825", "steps": {"step": ["in mixing bowl , cream the butter and brown '
#  'sugar", "beat in egg & vanilla", "combine dry ingredients", "gradually add '
#  'to the creamed mixture", {"@has_minutes": "1", "#text": "refrigerate for 30 '
#  'minutes"}, "roll into 1-inch balls", "place 2-inches apart on greased baking '
#  'sheets", "using the end of a wooden spoon handle , make an indentation in '
#  'the center of each ball", "combine filling ingredients", "spoon about 1 '
#  'teaspoonful into each cookie", {"@has_degrees": "1", "@has_minutes": "1", '
#  '"#text": "bake at 350 degrees for 11 to 13 minutes or until lightly '
#  'browned"}, {"@has_minutes": "1", "#text": "cool for 5 minutes before '
#  'removing to wire racks"}]}}, {"id": "47011", "steps": {"step": ["in an '
#  '8\\"x8\\" glass baking dish , mix first four ingredients", "add walnuts and '
#  'golden raisins", "stir in the milk", "when blended , smooth mixture in the '
#  'pan", "stir brown sugar , water , and butter until sugar dissoves , then '
#  'gently pour over the cake", {"@has_degrees": "1", "@has_minutes": "1", '
#  '"#text": "bake at 350 degrees for 30-35 minutes"}]}}, {"id": "424626", '
#  '"steps": {"step": ["heat tomatoes and zucchini in a wide skillet", '
#  '{"@has_minutes": "1", "#text": "bring to a simmer and cook uncovered 3 '
#  'minutes"}, "stir in taco seasoning , 2 tablespoons water , black beans and '
#  'corn", {"@has_minutes": "1", "#text": "cover and simmer 5 minutes"}, "stir '
#  'in walnuts", {"@has_minutes": "1", "#text": "let stand 1-2 minutes for sauce '
#  'to thicken"}, "serve in taco shells or soft tortillas with choice of '
#  'condiments like lettuce , cheese , sour cream , or avocado slices"]}}, '
#  '{"id": "69401", "steps": {"step": ["dough: soften yeast in warm water and '
#  'set aside", "in another bowl , combine flour , salt , then cut in margarine '
#  'to coarse crumbs", "add softened yeast and egg , then blend", "roll the '
#  'dough out on a floured surface to make two 9\\" x 13\\" rectangles", '
#  '"filling: beat cream cheese , 1 cup sugar and vanilla until fluffy", "spread '
#  'half of the filling mixture onto each rectangle of dough", "sprinkle with '
#  'chopped nuts", "rollup dough , starting from long side", "place seam side '
#  'down on lightly greased cookie sheet", "cut the roll about half way down , '
#  'through the center , lengthwise", {"@has_degrees": "1", "@has_minutes": "1", '
#  '"#text": "bake at 350 degrees for 20-25 minutes"}, "remove from oven , cool '
#  'slightly", "cut lengthwise , then diagonally into 1\\" pieces", "dust with '
#  'powdered sugar", "serve", "leftovers should be refrigerated", "hint: filling '
#  'may be colored to fit your mood or the holiday"]}}, {"id": "46527", "steps": '
#  '{"step": ["in a small bowl , mix together 1 cup walnuts , brown sugar , and '
#  'cinnamon", "in another bowl , add 1 / 3 cup flour", "cut in butter with '
#  'pastry blender until the consistancy of coarse crumbs", "add 3 / 4 cup of '
#  'the walnut mixture and stir to combine", "set walnut mixture and crumb '
#  'mixture aside", "in a bowl , toss pears with lemon juice", "set aside", "in '
#  'another bowl mix together 1 3 / 4 cup flour , baking powder , baking soda , '
#  'and salt", "set aside", "in yet another bowl , beat 1 / 2 cup butter on '
#  'medium speed of an electric mixer for 30 seconds", "beat in sugar and '
#  'vanilla", "add eggs , one at a time , and beat well after each addition '
#  'until well mixed", "alternately add the flour mixture and the sour cream to '
#  'egg mixture", "beat on low speed after each addition until combined", '
#  '"spread two-thirds of batter into a greased 9-inch springform pan", '
#  '"sprinkle with reserved walnut mixture", "layer pears evenly over walnut '
#  'mixture", "spread remaining batter over pears", "sprinkle with crumb '
#  'mixture", {"@has_degrees": "1", "@has_minutes": "1", "#text": "bake at 350 '
#  'degrees for 10 minutes"}, "sprinkle with 1 / 2 cup walnuts", '
#  '{"@has_minutes": "1", "#text": "bake 45-50 minutes longer or until tests '
#  'done"}, {"@has_minutes": "1", "#text": "cool in the pan on a wire rack for '
#  '10 minutes"}, "run a knife around the sides of the pan", "remove side of '
#  'springform pan", {"@has_hours": "1", "#text": "cool for 1 hour"}]}}, {"id": '
#  '"242587", "steps": {"step": ["boil potatoes in salted water until tender", '
#  '"drain", "add egg , bell pepper , onion and pimientos", "fold in mayo", "add '
#  'pepper to taste"]}}, {"id": "147473", "steps": {"step": ["on the night '
#  "before you need the roast for the next day's dinner , put the frozen roast "
#  'into the slow cooker on low temperature", "mix the cream of mushroom sup and '
#  'dried onion soup mix together and pour it over the roast", "leave it on all '
#  'night and the next day", {"@has_hours": "1", "#text": "the next day , about '
#  '1-2 hours before dinner , add the drained potatoes in and make sure they are '
#  'submerged in the gravy"}]}}, {"id": "131087", "steps": {"step": '
#  '[{"@has_degrees": "1", "#text": "heat oven to 400 degrees f"}, "in a bowl , '
#  'combine all ingredients", "place in 1-quart baking dish", "cover", '
#  '{"@has_minutes": "1", "#text": "heat 20 to 30 minutes or until hot"}, "serve '
#  'with assorted crackers and / or chips"]}}, {"id": "297805", "steps": '
#  '{"step": [{"@has_degrees": "1", "#text": "heat oven to 350 degrees"}, '
#  '"butter and flour 13x9-inch baking pan", {"@has_minutes": "1", "#text": '
#  '"place ice cream in refrigerator and let soften 20 minutes"}, "meanwhile , '
#  'prepare cake: using electric mixer , beat butter in large bowl until '
#  'creamy", "gradually beat in sugar and continue to beat until very light and '
#  'fluffy", "sift cake flour , baking powder , baking soda , and salt onto '
#  'sheet of waxed paper", "beat eggs into butter mixture one at a time", "beat '
#  'in vanilla", "reduce speed on mixer and mix dry ingredients and buttermilk '
#  'alternately into batter , beginning and ending with dry ingredients", "do n '
#  'ot overmix or cake will be tough", "pour batter into prepared pan and spread '
#  'evenly", "scatter apples evenly over top", "make topping: process flour , '
#  'walnuts , sugars , cinnamon and butter in food processor until butter pieces '
#  'are size of small peas", "add coconut and process until just combined", '
#  '{"@has_minutes": "1", "#text": "sprinkle cake until toothpick inserted in '
#  'center comes out clean , about 45 minutes"}, "while cake is baking , scoop 1 '
#  'pint ice cream into mixing bowl , sprinkle with half the 1-1 / 2 t", '
#  '"cinnamon , and fold lightly together with rubber spatula", "return ice '
#  'cream to container", "repeat with remaining ice cream and cinnmon", "freeze '
#  'until ready to serve"]}}, {"id": "183901", "steps": {"step": ["mound apples '
#  'in a buttered 9\\" pie plate , and sprinkle with the orange juice", "in a '
#  'large bowl , combine sugar , flour , spices , and oatmeal", "cut in butter '
#  'until well mixed and crumbly", "completely cover the apples with this '
#  'mixture", {"@has_minutes": "1", "#text": "bake at 375 for 45 minutes , or '
#  'until apples are tender , and top is crisp"}, "cool slightly", "serve warm '
#  'with or without icecream", "this can be re-warmed if made ahead of time"]}}, '
#  '{"id": "105180", "steps": {"step": ["sprinkle the top with goldschlager and '
#  'light it on fire", "blow it out , and slug it down"]}}, {"id": "424474", '
#  '"steps": {"step": ["bring potatoes to a boil over high heat with 1 tsp salt '
#  'added to water", "reduce heat to low", {"@has_minutes": "1", "#text": "cover '
#  'and simmer 10 to 12 minutes , or until potatoes are fork-tender"}, "drain", '
#  '"in a serving bowl , whisk vinegar , olive oil , sesame oil and remaining '
#  'teaspoons salt", "stir in red pepper , green onion , jalapeo , and '
#  'cilantro", "when potatoes are cool enough to handle , cut each lengthwise in '
#  'half", "add potatoes to bowl with dressing and toss to coat", "serve warm or '
#  'at room temperature"]}}, {"id": "382098", "steps": {"step": ["coat a medium '
#  'skillet with cooking spray", {"@has_minutes": "1", "#text": "saute the '
#  'tomatoes over medium-high heat until they soften , 2-3 minutes"}, "add the '
#  'scallions , onion , adn chile pepper", "reduce the heat to medium", "add the '
#  'avocado , lime juice , salt , and black pepper", "mix gently until the '
#  'avocado is just warm", "stir in the cilantro and serve immediately"]}}, '
#  '{"id": "219503", "steps": {"step": ["cook bacon til crisp , drain and '
#  'crumble", "add rest of ingredients and mix well", "serve over tomatoes , '
#  'boild potatoes , green beans or tossed salad"]}}, {"id": "210790", "steps": '
#  '{"step": ["combine spinach and mushrooms in salad bowl", "cook onion until '
#  'translucent , in olive oil", "combine cornstarch , apple juice and cider '
#  'vinegar together until well mixed", "add to skillet with onion and heat '
#  'until boiling", "while boiling continue to stir until mixture thickens '
#  'slightly", "stir in honey", "pour hot dressing over spinach mixture and mix '
#  'in well", "add boiled egg and bacon and toss thoroughly", "season to taste '
#  'with salt and pepper"]}}, {"id": "404253", "steps": {"step": ["clean , cube '
#  ', and bake potatoes", {"@has_minutes": "1", "#text": "once potatoes have '
#  'cooled for 5 minutes , transfer to large bowl"}, "fold potatoes , sour cream '
#  ', bacon , cheddar , and green onions together until well mixed", "serve '
#  'immediately and enjoy !"]}}, {"id": "369125", "steps": {"step": '
#  '[{"@has_minutes": "1", "#text": "cook bacon in heavy large skillet over '
#  'medium-high heat until almost crisp , about 7 minutes"}, "drain excess fat '
#  'from skillet", {"@has_minutes": "1", "#text": "add garlic and cook until '
#  'bacon is crisp , about 3 minutes"}, {"@has_degrees": "1", "#text": "preheat '
#  'oven to 350 degrees"}, "using electric mixer , beat cream cheese until '
#  'smooth", "add half and half and beat until combined", "stir in bacon mixture '
#  ', blue cheese and chives", "transfer to 2-cup ovenproof baking dish", "cover '
#  'with foil", {"@has_minutes": "1", "#text": "bake until heated through , '
#  'about 30 minutes"}, "sprinkle with chopped almonds and serve"]}}, {"id": '
#  '"147372", "steps": {"step": ["in a small bowl , mix pecans with butter", '
#  '"lay crpes on a counter in a single", "layer , pale side up", "spread each '
#  'crpe with about 2 tablespoons chutney", "thinly slice cheese , including '
#  'rind , and cut into about 1-inch lengths", "distribute cheese evenly over '
#  'crpes", "gently fold each crpe in half over filling , then in half again to '
#  'make a triangle", "set filled crpe triangles slightly apart on a 12- by '
#  '15-inch baking sheet", "lay 2 or 3 pecan halves on each crpe", '
#  '{"@has_minutes": "1", "#text": "bake in a 400 regular oven or 375 convection '
#  'oven until cheese melts and nuts are lightly toasted , 6 to 9 minutes"}, '
#  '"with a wide spatula , transfer crpes to plates"]}}, {"id": "206035", '
#  '"steps": {"step": ["heat oil in a saucepan over low heat", "add onion & cook '
#  'till softened", "add mustard to saucepan , then the vinegar & stir well", '
#  '"remove rind from brie & add cheese to the pan , mixing till smooth", "let '
#  'mixture cool slightly & add capers if you are using them", "add salt & '
#  'pepper to taste & serve warm over mixed salad greens"]}}, {"id": "320875", '
#  '"steps": {"step": ["heat 1 tablespoon of the oil in a frying pan over '
#  'medium-low heat", {"@has_minutes": "1", "#text": "add the onion and garlic & '
#  'cook gently for 57 minutes until soft and transparent"}, "add the chickpeas '
#  ', ginger , and chili flakes and stir for about 30 seconds", "then add the '
#  'lemon juice and let the mixture bubble until almost dry", "next add the '
#  'cilantro and season to taste with salt and pepper", "place the chickpea '
#  'mixture into a serving bowl and pour over the remaining olive oil", '
#  '"sprinkle the cumin and paprika on top , gently stir then serve warm"]}}, '
#  '{"id": "214923", "steps": {"step": ["preheat the oven to 350", "spray a '
#  '9-inch square baking pan with nonstick spray", "combine the flour , '
#  'granulated sugar , the 1 / 3 cup of cocoa powder , the baking powder , '
#  'espresso powder , baking soda , and salt in a large bowl", "make a well in '
#  'the center , and pour in the milk , melted butter , and vanilla", "stir just '
#  'until blended", "spoon the batter evenly into the pan", "combine the brown '
#  'sugar and additional 1 / 4 cup cocoa powder in a small bowl", "sprinkle '
#  'evenly over the batter", "gently pour the boiling water in a zigzag fashion '
#  'over the top", "do not stir", {"@has_minutes": "1", "#text": "bake until the '
#  'top of the pudding is set , about 35 minutes"}, {"@has_minutes": "1", '
#  '"#text": "cool on a rack at least 30 minutes"}, "cut into 9 squares and '
#  'serve warm or at room temperature"]}}, {"id": "429546", "steps": {"step": '
#  '["heat oil in deep frypan", {"@has_minutes": "1", "#text": "add onion and '
#  'chorizo , cook about 8 minutes till browned"}, {"@has_minutes": "1", '
#  '"#text": "add celery , garlic and thyme , cook further 5 minutes"}, '
#  '{"@has_minutes": "1", "#text": "add lentils , stock , salt and pepper , cook '
#  '25 minutes till lentils are tender"}, "remove from the heat , stir through '
#  'vinegar"]}}, {"id": "266945", "steps": {"step": ["in crockpot , combine '
#  'juices , red-hots and cinnamon stick", {"@has_hours": "1", "#text": "cook on '
#  'low for 2-5 hours"}, "remove cinnamon stick before serving", "use additional '
#  'cinnamon sticks as stirrers if desired"]}}, {"id": "391244", "steps": '
#  '{"step": ["preheat the oven to 425f", "place the peppers , zucchini and '
#  'garlic cloves in a bowl with a little oil and stir to coat everything '
#  'lightly", "meanwhile , pour 2 1 / 2 cups boiling water over the cous cous '
#  'and leave to soak until all the water has been absorbed", "remove the '
#  'vegetables from the oven and discard the garlic cloves", {"@has_minutes": '
#  '"1", "#text": "place the peppers in a plastic bag , knot the end and leave '
#  'for 10 minutes"}, "then peel off the skin and cut the flesh into strips", '
#  '"place the couscous in a large serving bowl", "stir well to break up any '
#  'lumps and add the warm vegetables , cherry tomatoes , feta and basil", "toss '
#  'together", "whisk all the dressing ingredients together and pour over", '
#  '"serve"]}}, {"id": "99395", "steps": {"step": ["preheat oven to 200c", "peel '
#  'strips off the eggplant skin with a vegetable peeler , slice eggplant into '
#  '1cm thick slices", "brush both sides with the extra olive oil , then place '
#  'in a baking dish and sprinkle with sea salt", {"@has_minutes": "1", "#text": '
#  '"cook for 30 minutes"}, {"@has_minutes": "1", "#text": "remove from oven , '
#  'if eggplant is a little dry , sprinkle with water , cool for 5 minutes , '
#  'then cut into 1 cm cubes and set aside"}, "heat olive oil in a skillet over '
#  'medium-high heat , add tomatoes , garlic , spices , chilli , sugar and '
#  'salt", {"@has_minutes": "1", "#text": "simmer for 10 minutes , remove from '
#  'heat and add juice , vinegar and black pepper"}, "add to the reserved '
#  'eggplant , stir through herbs", "serve warm or at room temperature"]}}, '
#  '{"id": "237851", "steps": {"step": ["peel and cut fruit into 1 inch chunks", '
#  '"thread fruit onto 8 pairs of soaked bamboo skewers , alternating '
#  'varieties", "in a small bowl , combine remaining ingredients to make basting '
#  'sauce", {"@has_minutes": "1", "#text": "grill kebabs uncovered over medium '
# ...
#  ', reduce heat and simmer for 5 minutes , stirring often"}, "stir in pasta '
#  'and cheese"]}}, {"id": "34481", "steps": {"step": [{"@has_minutes": "1", '
#  '"#text": "salt the zuke in a colander and allow to drain for 20 minutes"}, '
#  '{"@has_minutes": "1", "#text": "saute the zuke for 2 minutes"}, "pesto '
#  'sauce: put the basil , garlic and nuts in a food processor and pulverize the '
#  'leaves", "add oil and blend together", "stir in the cheese", "refrigerate '
#  'the sauce until ready for use", "add the pesto sauce to the sauted '
#  'zucchini", "season with salt& pepper and toss well to mix"]}}, {"id": '
#  '"162411", "steps": {"step": ["wash zucchini , cut in half and remove the '
#  'seeds", "the cut into cubes", "warm olive oil in a pan , add zucchini , '
#  'garlic , salt & pepper", "cook until done", "with fingers , shred the '
#  'serrano and spread over zucchini", "serve"]}}, {"id": "36349", "steps": '
#  '{"step": ["in a large bowl , combine the zucchini , corn , onion , jalapenos '
#  ', beans , salt , pepper , and chili powder", "toss gently to distribute the '
#  'seasonings and then stir in the cheese", {"@has_degrees": "1", "#text": '
#  '"heat the oven to 200 degrees f"}, "set the tortillas on a work surface", '
#  '"put about 1 / 3 cup of the filling on one half of each tortilla", "spread '
#  'the filling to the edge and then fold the tortilla over the filling", "in a '
#  'large nonstick frying pan , heat 1 / 2 tbs of the oil over moderate heat", '
#  '{"@has_minutes": "1", "#text": "add two of the quesadillas to the pan and '
#  'cook , turning once , until the cheese melts , about 1-1 / 2 minutes per '
#  'side"}, "remove from the pan and keep warm on a baking sheet in the oven", '
#  '"repeat in batches with the remaining oil and quesadillas", "cut the '
#  'quesadillas in wedges and serve"]}}, {"id": "325574", "steps": {"step": '
#  '["place zucchini , pineapples , habanero`s and crystallized ginger in a food '
#  'processor and puree", {"@has_minutes": "1", "#text": "add to a heavy bottom '
#  'pot with sugar and boil for 20 minutes"}, "that`s a rolling boil", "stirring '
#  'all the while", {"@has_minutes": "1", "#text": "add certo and bring to a '
#  'full rolling boil for 1 more minute add jello and stir to blend"}, "add some '
#  'red food coloring and more yellow to produce a color to your liking", "ladle '
#  'hot jam into hot jars leaving 1 / 4 inch head space", "wipe rim", "center '
#  'lid on jar", "apply band until fit is finger", {"@has_minutes": "1", '
#  '"#text": "process in a boiling water canner for 10 minutes , adjusting for '
#  'altitude"}, "remove jars and cool", {"@has_hours": "1", "#text": "check lids '
#  'for seal after 24 hours"}, "lid should not flex up and down when center is '
#  'pressed", "label , decorate , and gift !"]}}, {"id": "344542", "steps": '
#  '{"step": ["squeeze all the excess liquid from the potato , zucchini , onion '
#  'and garlic , and use paper kitchen towelling to further pat dry the potatoes '
#  ', zucchini and onion", "one method is to put the vegetables into a small '
#  'colandar or sieve , place this on or over the sink and press down on the '
#  'vegetables several times", "combine the potato , zucchini , onion , garlic , '
#  'flour , egg , mint , basil , pepper and salt in a large bowl", "pre-heat the '
#  'oven to hot", "220c or 425-450f or gas mark 7-8", {"@has_minutes": "1", '
#  '"#text": "heat oil in a large , preferably non-stick pan , and shallow-fry '
#  'level tablespoons of the mixture , until the fritters are browned on both '
#  'sides , place on paper kitchen towelling to absorb excess oil then transfer '
#  'the fritters to oven trays and bake uncovered for about 10 minutes or until '
#  'they are crisped and cooked right through"}, "combine the yoghurt and extra '
#  'mint", "serve the fritters immediately with the yoghurt and mint '
#  'topping"]}}, {"id": "112591", "steps": {"step": [{"@has_degrees": "1", '
#  '"#text": "preheat oven to 375 degrees"}, "beat eggs lightly in large bowl", '
#  '"add oil , sugar , and vanilla", "sift flour , baking powder , baking soda , '
#  'spices , and salt together", "gradually add to egg mixture until well '
#  'blended", "stir in raisins", "zucchini and carrots", {"@has_hours": "1", '
#  '"#text": "bake in a 10-inch tube pan for one hour or until center springs '
#  'back when lightly touched"}, {"@has_minutes": "1", "#text": "cool in pan for '
#  '20 minutes , then remove to wire rack"}, "when completely cool , frost with '
#  'cream cheese frosting", "cream cheese frosting:", "bring cream cheese to '
#  'room temperature or use soft philadelphia cream cheese", "add to container '
#  'of non-dairy whipped topping until well blended"]}}, {"id": "287490", '
#  '"steps": {"step": ["preheat oven to 350f spray the muffin tins", "whisk the '
#  'first six ingredients in a large bowl", "mix eggs , oil and sugar in a '
#  'medium bowl", "whisk for 30 seconds to dissolve sugar", "stir the shredded '
#  'zucchini and carrot", "stir egg mixture into the dry ingredients", "stir in '
#  'sunflower seeds", "divide batter into the muffin tins about 1 / 4 cup each", '
#  '{"@has_minutes": "1", "#text": "bake for 23 to 25 minutes or until crowned '
#  'and lightly browned"}]}}, {"id": "74023", "steps": {"step": '
#  '[{"@has_degrees": "1", "#text": "set oven to 350 degrees"}, "butter a 13x9 , '
#  'or smaller", "cook zucchini in a small amount of water until tender , about '
#  '15 mins", "drain and sprinkle with salt", "lightly beat egg yolks", "mix '
#  'with sour cream and flour", "beat egg whites until stiff", "fold in sour '
#  'cream mixture", "in a baking dish , layer half of the zucchini , half of the '
#  'sour cream mixture , and half of the cheese", "sprinkle with bacon", "repeat '
#  'layers of zucchini , sour cream mixture , and cheese", "combine crumbs with '
#  'butter", "sprinkle over top", {"@has_minutes": "1", "#text": "bake , '
#  'uncovered for 20-25 minutes"}]}}, {"id": "71450", "steps": {"step": '
#  '[{"@has_degrees": "1", "#text": "set oven to 350 degrees"}, "grease two 9 x '
#  '5-inch loaf pans , or mini loaf pans", "in a large bowl , beat eggs , oil , '
#  'sugar and vanilla , continue beating until thick and foamy with a spoon , '
#  'then stir in shredded zucchini and pineapple", "combine remaining dry '
#  'ingredients together , then gently stir into zucchini / pineapple mixture '
#  'just until blended", "add the chopped nut and raisins", "stir to combine", '
#  '"divide the batter evenly between two greased and floured 9x5 loaf pans", '
#  '{"@has_hours": "1", "#text": "bake for 1 hour or until cake tests done"}, '
#  '{"@has_minutes": "1", "#text": "cool in pans for 10 minutes before '
#  'removing"}, "muffin variation: follow above recipe except nearly fill '
#  'paper-lined muffin cups", {"@has_degrees": "1", "@has_minutes": "1", '
#  '"#text": "bake at 350 degrees for 24-30 minutes"}]}}, {"id": "180833", '
#  '"steps": {"step": ["shred the zucchini into a bowl using the large holes of '
#  'a box grater", "place the grated zucchini in a medium bowl and sprinkle with '
#  '1 / 2 to 1 teaspoon kosher salt", {"@has_minutes": "1", "#text": "transfer '
#  'zucchini to a colander in a bowl and let zucchini drain at least 15 minutes '
#  'and up to 30 minutes"}, "using your hands or a towel , squeeze out the '
#  'excess liquid", "shred the potato into a bowl using the large holes of a box '
#  'grater", "in a bowl , mix together the onion , egg , and flour , and pepper '
#  'to taste", "add zucchini and potatoes", "mix well", "work quickly because '
#  'the zucchini-potato mixture oxidizes and discolors once hit by the fresh '
#  'air", "heat 2 to 4 tablespoons of the oil in a large skillet over medium-low '
#  'heat", "when the pan is hot enough to create a small sizzle , ladle the '
#  'mixture into the pan to form six 4-inch cakes", {"@has_minutes": "1", '
#  '"#text": "fry until golden on the bottom , 7 to 10 minutes"}, '
#  '{"@has_minutes": "1", "#text": "using a spatula , turn the pancakes over '
#  'until browned on the second side , about 6 minutes longer"}, "serve at once '
#  'with a dollop of sour cream"]}}, {"id": "415406", "steps": {"step": ["put '
#  'the potatoes and onions into a large saucepan with the chicken broth and '
#  'chicken stock cube", {"@has_minutes": "1", "#text": "bring to a boil and '
#  'simmer for 3 minutes"}, {"@has_minutes": "1", "#text": "add the zucchini , '
#  'garlic and cavenders seasoning and simmer , covered , for 30 minutes"}, "add '
#  'the cream cheese and salt and pepper if using", "blend in a food processor '
#  'or with a handheld blender until smooth , reheat if necessary , and serve '
#  '!"]}}, {"id": "316950", "steps": {"step": ["wash and trim the zucchini , '
#  'then slice them one-sixteenth-inch thick", "a mandoline works best", "slice '
#  'the onion very thin as well", "combine the zucchini and onions in a large '
#  'but shallow nonreactive bowl , add the salt and toss to distribute", "add a '
#  'few ice cubes and cold water to cover , then stir to dissolve the salt", '
#  '{"@has_hours": "1", "#text": "after about 1 hour , taste and feel a piece of '
#  'zucchini -- it should be slightly softened"}, "drain and pat dry", '
#  '{"@has_minutes": "1", "#text": "combine the vinegar , sugar , dry mustard , '
#  'mustard seeds and turmeric in a small saucepan and simmer for 3 minutes"}, '
#  '"set aside until just warm to the touch", "return the zucchini to a dry bowl '
#  'and pour over the cooled brine", "stir to distribute the spices", "transfer '
#  'the pickle to jars , preferably ones that have \\"shoulders\\" to hold the '
#  'zucchini and onions beneath the surface of the brine", "seal tightly and '
#  'refrigerate for at least a day before serving to allow the flavors to mellow '
#  'and permeate the zucchini , turning them a brilliant chartreuse color"]}}, '
#  '{"id": "464576", "steps": {"step": ["remove and discard the casing from the '
#  'sausage", "cook the sausage in a large skillet over medium heat until the '
#  'sausage is browned , stirring to crumble meat", "drain well , and set '
#  'aside", "saute the onion and garlic in oil in a large dutch oven until '
#  'tender", "add the reserved sausage and broth", "stir well", "bring to a '
#  'boil", "stir in the cabbage and next 9 ingredients", "return the mixture to '
#  'a boil", {"@has_minutes": "1", "#text": "cover , reduce heat , and simmer '
#  'for 15 minutes"}, "add macaroni", {"@has_minutes": "1", "#text": "simmer , '
#  'uncovered for 15 minutes or until the macaroni is tender"}, "ladle the soup '
#  'into individual soup bowls", "sprinkle each serving with pamesan cheese"]}}, '
#  '{"id": "267661", "steps": {"step": ["grease a bread tin very well with '
#  'butter", "mine have slightly sloping sides and measure , on the bottom , 3 1 '
#  '/ 4 x 7 1 / 2\\" , and is about 2 \\" deep", "heat oven to 350 deg f / 180 '
#  'deg c , or slightly less if you have a convection oven", "drain the olives '
#  'and pat dry with kitchen paper", "slice all of them into rounds", "grate the '
#  'cheese on the large holes of your cheese grater , weigh , and keep", "put '
#  'the flour into a bowl , break in the eggs , and whisk with electric beater", '
#  '"the eggs and flour will form small clumps", "add the baking powder , white '
#  'wine , olive oil and creme fraiche to the flour-and-egg mixture", "whisk or '
#  'beat until batter is smooth", "fold in the sliced olives and the cheese , '
#  'folding in well", "add the black pepper , and strew over a pinch of salt if '
#  "you like , although it's not strictly necessary due to the salty olives and "
#  'the cheese", "scrape the cake-like batter into the greased tin and smooth '
#  'the top", {"@has_minutes": "1", "#text": "bake for 55 - 60 minutes"}, "best '
#  'is to test with a skewer , which should come out clean when bread is done", '
#  '"turn out and cool on a rack"]}}, {"id": "386977", "steps": {"step": ["in a '
#  'small bowl , combine the yeast and half of the milk", "mix in 2 tablespoons '
#  'of the flour and 1 teaspoon of the sugar", {"@has_hours": "1", "#text": '
#  '"allow this mixture to sit in a warm place for 1 hour"}, "combine remaining '
#  'dough ingredients then add in the yeast mixture", "mix until a smooth dough '
#  'forms , then knead by hand", "allow dough to sit in a warm place until '
#  'double in volume", "preheat oven to 350f", "grease a baking sheet", "roll '
#  'out dough to fit the size of the baking sheet", "transfer dough to baking '
#  'sheet", "wash plums and remove any stems", "slice each in half and remove '
#  'stones", "arrange plum halves evenly on the dough - plums should not be '
#  'lying down , instead they should be standing stem-side up", "sprinkle plums '
#  'with sugar", "crumbs are optional", "if you choose to add them , prepare the '
#  'crumbs by mixing the butter , vanilla sugar , and sugar", "gradually work in '
#  'flour until mixture becomes dry and crumbly", "sprinkle crumbs over dough , '
#  'distributing them evenly", {"@has_minutes": "1", "#text": "allow cake to sit '
#  'and rise for another 30 minutes"}, {"@has_minutes": "1", "#text": "bake cake '
#  'for around 30-40 minutes or until crumbs and crust become golden brown"}, '
#  '"remove cake from oven and allow to cool completely", "serve at room '
#  'temperature , with a dollop of whipped cream"]}}, {"id": "103312", "steps": '
#  '{"step": ["for the dough:", {"@has_minutes": "1", "#text": "dissolve the '
#  'yeast in the lukewarm milk , and add the sugar and a dash of the flour , '
#  'stir , cover and keep in a warm place for ten minutes"}, "add the rest of '
#  'the dough ingredients in the pastry mixer and blend until you have a ball", '
#  '{"@has_minutes": "1", "#text": "cover and keep in a warm place for twenty '
#  'minutes until the dough rises"}, "preheat the oven to 225c", "saute the '
#  "onion'rings' with the bacon in a large skillet , until the onions are "
#  'transparent , and soft , but not caramelized", {"@has_minutes": "1", '
#  '"#text": "this should take about 10-15 minutes"}, "in a seperate bowl , mix '
#  'the eggs , the creme fraiche , the nutmeg , and pepper together with a whisk '
#  'until well incorporated and smooth", "roll the dough out into a flat , large '
#  'roasting pan and then pour the onion and bacon mixture over the dough and '
#  'spread it out to cover the dough evenly", {"@has_minutes": "1", "#text": '
#  '"pour the egg-creme fraich mixture over the top and put it in the oven for '
#  '30-40 minutes , or until golden brown on top"}]}}, {"id": "486161", "steps": '
#  '{"step": ["heat oil in a 4-quart dutch oven", "add celery , onion , sweet '
#  'pepper and garlic", {"@has_minutes": "1", "#text": "cook for 5 minutes over '
#  'medium heat"}, "stir in ham , paprika , sugar , dry mustard , cumin , basil '
#  ', oregano , thyme , cloves , black pepper and cayenne pepper", '
#  '{"@has_minutes": "1", "#text": "cook for 5 more minutes , stirring '
#  'frequently"}, "stir in black-eyed peas , hominy , undrained tomatoes , '
#  'chicken broth , parsley and molasses", {"@has_minutes": "1", "#text": "bring '
#  'to boil , then reduce heat and cover dutch over and let soup simmer for 30 '
#  'minutes"}]}}, {"id": "298512", "steps": {"step": ["place melted butter in a '
#  'large mixing bowl and add each remaining ingredient as listed , beating well '
#  'after each addition to achieve a smooth dough", {"@has_minutes": "1", '
#  '"#text": "let dough stand uncovered 10 minutes"}, "make golf-ball-sized '
#  'shapes of the dough and insert a flat , wooden popsicle stick into one side '
#  'of each ball", "carefully flatten each ball of dough to a 1 / 2 inch thick '
#  'patty", "place 3 inches apart on greased baking sheets", {"@has_minutes": '
#  '"1", "#text": "bake at 400f for 6-8 minutes or til just browned around the '
#  'edges , but still white on tops of cookies"}, "remove from the oven and '
#  'smear the top of each cookie generously with heated , canned , '
#  'ready-to-spread frosting", "frostings may be tinted with few drops food '
#  'coloring once it has been heated", {"@has_minutes": "1", "#text": "let '
#  'cookies cool on baking sheet 10 minutes before carefully removing to paper '
#  'towels"}]}}]}}')

# %% [markdown]
# 3.2 По данным файла `steps_sample.xml` сформируйте словарь следующего вида: `кол-во_шагов_в_рецепте: [список_id_рецептов]`

# %% [markdown]
# 3.3 Получите список рецептов, в этапах выполнения которых есть информация о времени (часы или минуты). Для отбора подходящих рецептов обратите внимание на атрибуты соответствующих тэгов.

# %% [markdown]
# 3.4 Загрузите данные из файла `recipes_sample.csv` (__ЛР2__) в таблицу `recipes`. Для строк, которые содержат пропуски в столбце `n_steps`, заполните этот столбец на основе файла  `steps_sample.xml`. Строки, в которых столбец `n_steps` заполнен, оставьте без изменений.

# %% [markdown]
# 3.5 Проверьте, содержит ли столбец `n_steps` пропуски. Если нет, то преобразуйте его к целочисленному типу и сохраните результаты в файл `recipes_sample_with_filled_nsteps.csv`
